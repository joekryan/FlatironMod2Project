# %% [markdown]
# # Module 2 Project

# %%
import pandas as pd
import sqlite3
import requests
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
conn = sqlite3.connect('database.sqlite')

c = conn.cursor()

# %% [markdown]
# # Initial examination of database

# %%
# https://www.kaggle.com/laudanum/footballdelphi
# Used SQL and schema from kaggle to export data from the four tables
# to panda dataframe and examine there

c.execute("""
SELECT *
FROM Matches
""")
df_matches = pd.DataFrame(c.fetchall())
df_matches.columns = [x[0] for x in c.description]
print(df_matches.info())
print(df_matches.shape)
df_matches
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24625 entries, 0 to 24624
# Data columns (total 9 columns):
# Match_ID    24625 non-null int64
# Div         24625 non-null object
# Season      24625 non-null int64
# Date        24625 non-null object
# HomeTeam    24625 non-null object
# AwayTeam    24625 non-null object
# FTHG        24625 non-null int64
# FTAG        24625 non-null int64
# FTR         24625 non-null object
# dtypes: int64(4), object(5)
# memory usage: 1.7+ MB
# None
# (24625, 9)
#        Match_ID Div  Season        Date       HomeTeam        AwayTeam  FTHG  \
# 0             1  D2    2009  2010-04-04     Oberhausen  Kaiserslautern     2
# 1             2  D2    2009  2009-11-01    Munich 1860  Kaiserslautern     0
# 2             3  D2    2009  2009-10-04  Frankfurt FSV  Kaiserslautern     1
# 3             4  D2    2009  2010-02-21  Frankfurt FSV       Karlsruhe     2
# 4             5  D2    2009  2009-12-06          Ahlen       Karlsruhe     1
# ...         ...  ..     ...         ...            ...             ...   ...
# 24620     46770  E0    2016  2017-05-21      Liverpool   Middlesbrough     3
# 24621     46771  E0    2016  2017-05-21     Man United  Crystal Palace     2
# 24622     46772  E0    2016  2017-05-21    Southampton           Stoke     0
# 24623     46773  E0    2016  2017-05-21        Swansea       West Brom     2
# 24624     46774  E0    2016  2017-05-21        Watford        Man City     0
#
#        FTAG FTR
# 0         1   H
# 1         1   A
# 2         1   D
# 3         1   H
# 4         3   A
# ...     ...  ..
# 24620     0   H
# 24621     0   H
# 24622     1   A
# 24623     1   H
# 24624     5   A
#
# [24625 rows x 9 columns]

# %%
c.execute("""
SELECT *
FROM Teams""")
df_teams = pd.DataFrame(c.fetchall())
df_teams.columns = [x[0] for x in c.description]
print(df_teams.shape)
print(df_teams.info())
df_teams
# Out:
# (468, 8)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 468 entries, 0 to 467
# Data columns (total 8 columns):
# Season                    468 non-null object
# TeamName                  468 non-null object
# KaderHome                 468 non-null object
# AvgAgeHome                468 non-null object
# ForeignPlayersHome        468 non-null object
# OverallMarketValueHome    468 non-null object
# AvgMarketValueHome        468 non-null object
# StadiumCapacity           468 non-null object
# dtypes: object(8)
# memory usage: 29.4+ KB
# None
#     Season       TeamName KaderHome AvgAgeHome ForeignPlayersHome  \
# 0     2017  Bayern Munich        27         26                 15
# 1     2017       Dortmund        33         25                 18
# 2     2017     Leverkusen        31         24                 15
# 3     2017     RB Leipzig        30         23                 15
# 4     2017     Schalke 04        29         24                 17
# ..     ...            ...       ...        ...                ...
# 463   2005      Paderborn        33         24                 13
# 464   2005   Unterhaching        28         26                  9
# 465   2005      Offenbach        28         26                 13
# 466   2005         Siegen        29         26                 13
# 467   2005   Braunschweig        25         25                  3
#
#     OverallMarketValueHome AvgMarketValueHome StadiumCapacity
# 0                597950000           22150000           75000
# 1                416730000           12630000           81359
# 2                222600000            7180000           30210
# 3                180130000            6000000           42959
# 4                179550000            6190000           62271
# ..                     ...                ...             ...
# 463                7530000             228000           47728
# 464                7030000             251000           47728
# 465                6280000             224000           47728
# 466                6180000             213000           47728
# 467                4150000             166000           47728
#
# [468 rows x 8 columns]

# %%
# Examine Shape of Database

c.execute("""
SELECT *
FROM Teams_in_Matches""")
df_teams_in_matches = pd.DataFrame(c.fetchall())
df_teams_in_matches.columns = [x[0] for x in c.description]
print(df_teams_in_matches.shape)
print(df_teams_in_matches.info())
df_teams_in_matches
# Out:
# (49148, 2)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49148 entries, 0 to 49147
# Data columns (total 2 columns):
# Match_ID          49148 non-null int64
# Unique_Team_ID    49148 non-null int64
# dtypes: int64(2)
# memory usage: 768.1 KB
# None
#        Match_ID  Unique_Team_ID
# 0             1              26
# 1             1              46
# 2             2              26
# 3             2              42
# 4             3              26
# ...         ...             ...
# 49143     46772             123
# 49144     46773             117
# 49145     46773             126
# 49146     46774              85
# 49147     46774             112
#
# [49148 rows x 2 columns]

# %%
# Examine Shape of Database

c.execute("""
SELECT *
FROM Unique_Teams""")
df_unique_teams = pd.DataFrame(c.fetchall())
df_unique_teams.columns = [x[0] for x in c.description]
print(df_unique_teams.shape)
print(df_unique_teams.info())
df_unique_teams
# Out:
# (128, 2)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 2 columns):
# TeamName          128 non-null object
# Unique_Team_ID    128 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 2.1+ KB
# None
#           TeamName  Unique_Team_ID
# 0    Bayern Munich               1
# 1         Dortmund               2
# 2       Leverkusen               3
# 3       RB Leipzig               4
# 4       Schalke 04               5
# ..             ...             ...
# 123        Burnley             124
# 124      Blackpool             125
# 125        Swansea             126
# 126        Cardiff             127
# 127    Bournemouth             128
#
# [128 rows x 2 columns]

# %%
c.execute("""
SELECT *
FROM Matches
WHERE Season = 2011
""")
df_matches = pd.DataFrame(c.fetchall())
df_matches.columns = [x[0] for x in c.description]
df_matches
# Out:
#      Match_ID Div  Season        Date    HomeTeam       AwayTeam  FTHG  FTAG  \
# 0        1092  D1    2011  2012-03-31    Nurnberg  Bayern Munich     0     1
# 1        1093  D1    2011  2011-12-11   Stuttgart  Bayern Munich     1     2
# 2        1094  D1    2011  2011-08-13   Wolfsburg  Bayern Munich     0     1
# 3        1095  D1    2011  2011-11-27       Mainz  Bayern Munich     3     2
# 4        1096  D1    2011  2012-02-18    Freiburg  Bayern Munich     0     0
# ..        ...  ..     ...         ...         ...            ...   ...   ...
# 987     44870  E0    2011  2012-05-13  Sunderland     Man United     0     1
# 988     44871  E0    2011  2012-05-13     Swansea      Liverpool     1     0
# 989     44872  E0    2011  2012-05-13   Tottenham         Fulham     2     0
# 990     44873  E0    2011  2012-05-13   West Brom        Arsenal     2     3
# 991     44874  E0    2011  2012-05-13       Wigan         Wolves     3     2
#
#     FTR
# 0     A
# 1     A
# 2     A
# 3     H
# 4     D
# ..   ..
# 987   A
# 988   H
# 989   H
# 990   A
# 991   H
#
# [992 rows x 9 columns]

# %%
df_matches['HomeTeam'].nunique()
# Out:
# 56

# %%
df_unique_teams.nunique()
# Out:
# TeamName          128
# Unique_Team_ID    128
# dtype: int64

# %% [markdown]
# # First Question: Total Number of Goals Scored Per Team in 2011 Season

# %%
#number of goals scored in home matches per team

Home_Goals = df_matches.groupby('HomeTeam')['FTHG'].sum()
Home_Goals
# Out:
# HomeTeam
# Aachen                15
# Arsenal               39
# Aston Villa           20
# Augsburg              20
# Bayern Munich         49
# Blackburn             26
# Bochum                23
# Bolton                23
# Braunschweig          21
# Chelsea               41
# Cottbus               18
# Dortmund              44
# Dresden               30
# Duisburg              23
# Ein Frankfurt         38
# Erzgebirge Aue        19
# Everton               28
# FC Koln               20
# Fortuna Dusseldorf    35
# Frankfurt FSV         20
# Freiburg              24
# Fulham                36
# Greuther Furth        46
# Hamburg               19
# Hannover              31
# Hansa Rostock         20
# Hertha                19
# Hoffenheim            21
# Ingolstadt            28
# Kaiserslautern        12
# Karlsruhe             23
# Leverkusen            28
# Liverpool             24
# M'gladbach            29
# Mainz                 27
# Man City              55
# Man United            52
# Munich 1860           35
# Newcastle             29
# Norwich               28
# Nurnberg              22
# Paderborn             28
# QPR                   24
# Schalke 04            47
# St Pauli              36
# Stoke                 25
# Stuttgart             36
# Sunderland            26
# Swansea               27
# Tottenham             39
# Union Berlin          30
# Werder Bremen         31
# West Brom             21
# Wigan                 22
# Wolfsburg             29
# Wolves                19
# Name: FTHG, dtype: int64

# %%
#number of goals scored in away matches per team

Away_Goals = df_matches.groupby('AwayTeam')['FTAG'].sum()
Away_Goals
# Out:
# AwayTeam
# Aachen                15
# Arsenal               35
# Aston Villa           17
# Augsburg              16
# Bayern Munich         28
# Blackburn             22
# Bochum                18
# Bolton                23
# Braunschweig          16
# Chelsea               24
# Cottbus               12
# Dortmund              36
# Dresden               20
# Duisburg              19
# Ein Frankfurt         38
# Erzgebirge Aue        12
# Everton               22
# FC Koln               19
# Fortuna Dusseldorf    29
# Frankfurt FSV         23
# Freiburg              21
# Fulham                12
# Greuther Furth        27
# Hamburg               16
# Hannover              10
# Hansa Rostock         14
# Hertha                19
# Hoffenheim            20
# Ingolstadt            15
# Kaiserslautern        12
# Karlsruhe             11
# Leverkusen            24
# Liverpool             23
# M'gladbach            20
# Mainz                 20
# Man City              38
# Man United            37
# Munich 1860           27
# Newcastle             27
# Norwich               24
# Nurnberg              16
# Paderborn             23
# QPR                   19
# Schalke 04            27
# St Pauli              23
# Stoke                 11
# Stuttgart             27
# Sunderland            19
# Swansea               17
# Tottenham             27
# Union Berlin          25
# Werder Bremen         18
# West Brom             24
# Wigan                 20
# Wolfsburg             18
# Wolves                21
# Name: FTAG, dtype: int64

# %%
#combined home goals and away golas into total goals per team

Home_Goals = df_matches.groupby('HomeTeam')['FTHG'].sum()
Away_Goals = df_matches.groupby('AwayTeam')['FTAG'].sum()

df_Total_Goals = pd.DataFrame(data = Home_Goals + Away_Goals).reset_index()

df_Total_Goals.columns = ['TeamName', 'TotalGoals']
df_Total_Goals
# Out:
#               TeamName  TotalGoals
# 0               Aachen          30
# 1              Arsenal          74
# 2          Aston Villa          37
# 3             Augsburg          36
# 4        Bayern Munich          77
# 5            Blackburn          48
# 6               Bochum          41
# 7               Bolton          46
# 8         Braunschweig          37
# 9              Chelsea          65
# 10             Cottbus          30
# 11            Dortmund          80
# 12             Dresden          50
# 13            Duisburg          42
# 14       Ein Frankfurt          76
# 15      Erzgebirge Aue          31
# 16             Everton          50
# 17             FC Koln          39
# 18  Fortuna Dusseldorf          64
# 19       Frankfurt FSV          43
# 20            Freiburg          45
# 21              Fulham          48
# 22      Greuther Furth          73
# 23             Hamburg          35
# 24            Hannover          41
# 25       Hansa Rostock          34
# 26              Hertha          38
# 27          Hoffenheim          41
# 28          Ingolstadt          43
# 29      Kaiserslautern          24
# 30           Karlsruhe          34
# 31          Leverkusen          52
# 32           Liverpool          47
# 33          M'gladbach          49
# 34               Mainz          47
# 35            Man City          93
# 36          Man United          89
# 37         Munich 1860          62
# 38           Newcastle          56
# 39             Norwich          52
# 40            Nurnberg          38
# 41           Paderborn          51
# 42                 QPR          43
# 43          Schalke 04          74
# 44            St Pauli          59
# 45               Stoke          36
# 46           Stuttgart          63
# 47          Sunderland          45
# 48             Swansea          44
# 49           Tottenham          66
# 50        Union Berlin          55
# 51       Werder Bremen          49
# 52           West Brom          45
# 53               Wigan          42
# 54           Wolfsburg          47
# 55              Wolves          40

# %% [markdown]
# # Question 2: Total Number of Wins Per Team in 2011 Season

# %%
#calculate home wins and away wins and combine for total wins

Home_Wins = df_matches[df_matches['FTR'] == 'H']['HomeTeam'].value_counts()
Away_Wins = df_matches[df_matches['FTR'] == 'A']['AwayTeam'].value_counts()

df_Total_Wins = pd.DataFrame(data = Home_Wins + Away_Wins).reset_index()
df_Total_Wins.columns = ['TeamName', 'TotalWins']
df_Total_Wins
# Out:
#               TeamName  TotalWins
# 0               Aachen          6
# 1              Arsenal         21
# 2          Aston Villa          7
# 3             Augsburg          8
# 4        Bayern Munich         23
# 5            Blackburn          8
# 6               Bochum         10
# 7               Bolton         10
# 8         Braunschweig         10
# 9              Chelsea         18
# 10             Cottbus          8
# 11            Dortmund         25
# 12             Dresden         12
# 13            Duisburg         10
# 14       Ein Frankfurt         20
# 15      Erzgebirge Aue          8
# 16             Everton         15
# 17             FC Koln          8
# 18  Fortuna Dusseldorf         16
# 19       Frankfurt FSV          7
# 20            Freiburg         10
# 21              Fulham         14
# 22      Greuther Furth         20
# 23             Hamburg          8
# 24            Hannover         12
# 25       Hansa Rostock          5
# 26              Hertha          7
# 27          Hoffenheim         10
# 28          Ingolstadt          8
# 29      Kaiserslautern          4
# 30           Karlsruhe          9
# 31          Leverkusen         15
# 32           Liverpool         14
# 33          M'gladbach         17
# 34               Mainz          9
# 35            Man City         28
# 36          Man United         28
# 37         Munich 1860         17
# 38           Newcastle         19
# 39             Norwich         12
# 40            Nurnberg         12
# 41           Paderborn         17
# 42                 QPR         10
# 43          Schalke 04         20
# 44            St Pauli         18
# 45               Stoke         11
# 46           Stuttgart         15
# 47          Sunderland         11
# 48             Swansea         12
# 49           Tottenham         20
# 50        Union Berlin         14
# 51       Werder Bremen         11
# 52           West Brom         13
# 53               Wigan         11
# 54           Wolfsburg         13
# 55              Wolves          5

# %%
#combine total goals and total wins into one dataframe

df_goals_and_wins = pd.merge(df_Total_Goals, df_Total_Wins, on='TeamName')

df_goals_and_wins
# Out:
#               TeamName  TotalGoals  TotalWins
# 0               Aachen          30          6
# 1              Arsenal          74         21
# 2          Aston Villa          37          7
# 3             Augsburg          36          8
# 4        Bayern Munich          77         23
# 5            Blackburn          48          8
# 6               Bochum          41         10
# 7               Bolton          46         10
# 8         Braunschweig          37         10
# 9              Chelsea          65         18
# 10             Cottbus          30          8
# 11            Dortmund          80         25
# 12             Dresden          50         12
# 13            Duisburg          42         10
# 14       Ein Frankfurt          76         20
# 15      Erzgebirge Aue          31          8
# 16             Everton          50         15
# 17             FC Koln          39          8
# 18  Fortuna Dusseldorf          64         16
# 19       Frankfurt FSV          43          7
# 20            Freiburg          45         10
# 21              Fulham          48         14
# 22      Greuther Furth          73         20
# 23             Hamburg          35          8
# 24            Hannover          41         12
# 25       Hansa Rostock          34          5
# 26              Hertha          38          7
# 27          Hoffenheim          41         10
# 28          Ingolstadt          43          8
# 29      Kaiserslautern          24          4
# 30           Karlsruhe          34          9
# 31          Leverkusen          52         15
# 32           Liverpool          47         14
# 33          M'gladbach          49         17
# 34               Mainz          47          9
# 35            Man City          93         28
# 36          Man United          89         28
# 37         Munich 1860          62         17
# 38           Newcastle          56         19
# 39             Norwich          52         12
# 40            Nurnberg          38         12
# 41           Paderborn          51         17
# 42                 QPR          43         10
# 43          Schalke 04          74         20
# 44            St Pauli          59         18
# 45               Stoke          36         11
# 46           Stuttgart          63         15
# 47          Sunderland          45         11
# 48             Swansea          44         12
# 49           Tottenham          66         20
# 50        Union Berlin          55         14
# 51       Werder Bremen          49         11
# 52           West Brom          45         13
# 53               Wigan          42         11
# 54           Wolfsburg          47         13
# 55              Wolves          40          5

# %% [markdown]
# # Question 3: Visualisation of Each Team's Wins and Losses in 2011 Season

# %%
#Calculated total losses 

Away_losses = df_matches[df_matches['FTR'] == 'A']['HomeTeam'].value_counts()
Home_losses = df_matches[df_matches['FTR'] == 'H']['AwayTeam'].value_counts()

df_Total_Losses = pd.DataFrame(data = (Away_losses + Home_losses)).reset_index()
df_Total_Losses.columns = ['TeamName', 'TotalLosses']
df_Total_Losses['TotalLosses'].fillna(0, inplace=True)
df_Total_Losses
# Out:
#               TeamName  TotalLosses
# 0               Aachen         15.0
# 1              Arsenal         10.0
# 2          Aston Villa         14.0
# 3             Augsburg         12.0
# 4        Bayern Munich          7.0
# 5            Blackburn         23.0
# 6               Bochum         17.0
# 7               Bolton         22.0
# 8         Braunschweig          9.0
# 9              Chelsea         10.0
# 10             Cottbus         15.0
# 11            Dortmund          3.0
# 12             Dresden         13.0
# 13            Duisburg         15.0
# 14       Ein Frankfurt          6.0
# 15      Erzgebirge Aue         15.0
# 16             Everton         12.0
# 17             FC Koln         20.0
# 18  Fortuna Dusseldorf          4.0
# 19       Frankfurt FSV         13.0
# 20            Freiburg         14.0
# 21              Fulham         14.0
# 22      Greuther Furth          4.0
# 23             Hamburg         14.0
# 24            Hannover          0.0
# 25       Hansa Rostock         17.0
# 26              Hertha         17.0
# 27          Hoffenheim         13.0
# 28          Ingolstadt         13.0
# 29      Kaiserslautern         19.0
# 30           Karlsruhe         19.0
# 31          Leverkusen         10.0
# 32           Liverpool         14.0
# 33          M'gladbach          8.0
# 34               Mainz         13.0
# 35            Man City          0.0
# 36          Man United          5.0
# 37         Munich 1860         11.0
# 38           Newcastle         11.0
# 39             Norwich         15.0
# 40            Nurnberg         16.0
# 41           Paderborn          7.0
# 42                 QPR         21.0
# 43          Schalke 04         10.0
# 44            St Pauli          8.0
# 45               Stoke         15.0
# 46           Stuttgart         11.0
# 47          Sunderland         15.0
# 48             Swansea         15.0
# 49           Tottenham          9.0
# 50        Union Berlin         14.0
# 51       Werder Bremen         14.0
# 52           West Brom         17.0
# 53               Wigan         17.0
# 54           Wolfsburg         16.0
# 55              Wolves         23.0

# %%
#combine total goals, total wins and total losses for each team in 2011 season into one dataframe

df_goals_and_wins_and_losses = pd.merge(df_goals_and_wins, df_Total_Losses, on='TeamName')

df_goals_and_wins_and_losses
# Out:
#               TeamName  TotalGoals  TotalWins  TotalLosses
# 0               Aachen          30          6         15.0
# 1              Arsenal          74         21         10.0
# 2          Aston Villa          37          7         14.0
# 3             Augsburg          36          8         12.0
# 4        Bayern Munich          77         23          7.0
# 5            Blackburn          48          8         23.0
# 6               Bochum          41         10         17.0
# 7               Bolton          46         10         22.0
# 8         Braunschweig          37         10          9.0
# 9              Chelsea          65         18         10.0
# 10             Cottbus          30          8         15.0
# 11            Dortmund          80         25          3.0
# 12             Dresden          50         12         13.0
# 13            Duisburg          42         10         15.0
# 14       Ein Frankfurt          76         20          6.0
# 15      Erzgebirge Aue          31          8         15.0
# 16             Everton          50         15         12.0
# 17             FC Koln          39          8         20.0
# 18  Fortuna Dusseldorf          64         16          4.0
# 19       Frankfurt FSV          43          7         13.0
# 20            Freiburg          45         10         14.0
# 21              Fulham          48         14         14.0
# 22      Greuther Furth          73         20          4.0
# 23             Hamburg          35          8         14.0
# 24            Hannover          41         12          0.0
# 25       Hansa Rostock          34          5         17.0
# 26              Hertha          38          7         17.0
# 27          Hoffenheim          41         10         13.0
# 28          Ingolstadt          43          8         13.0
# 29      Kaiserslautern          24          4         19.0
# 30           Karlsruhe          34          9         19.0
# 31          Leverkusen          52         15         10.0
# 32           Liverpool          47         14         14.0
# 33          M'gladbach          49         17          8.0
# 34               Mainz          47          9         13.0
# 35            Man City          93         28          0.0
# 36          Man United          89         28          5.0
# 37         Munich 1860          62         17         11.0
# 38           Newcastle          56         19         11.0
# 39             Norwich          52         12         15.0
# 40            Nurnberg          38         12         16.0
# 41           Paderborn          51         17          7.0
# 42                 QPR          43         10         21.0
# 43          Schalke 04          74         20         10.0
# 44            St Pauli          59         18          8.0
# 45               Stoke          36         11         15.0
# 46           Stuttgart          63         15         11.0
# 47          Sunderland          45         11         15.0
# 48             Swansea          44         12         15.0
# 49           Tottenham          66         20          9.0
# 50        Union Berlin          55         14         14.0
# 51       Werder Bremen          49         11         14.0
# 52           West Brom          45         13         17.0
# 53               Wigan          42         11         17.0
# 54           Wolfsburg          47         13         16.0
# 55              Wolves          40          5         23.0

# %%
#Plotted all teams on same chart for easy comparison between teams
#set two different y axes on same chart, one for Total Wins and one for Total Goals

sns.set()

df = df_goals_and_wins_and_losses.set_index('TeamName')

fig = plt.figure(figsize=(25,12)) 
ax = fig.add_subplot(111) 
ax2 = ax.twinx() 
width = .4

df.TotalWins.plot(kind='bar',color='blue',ax=ax,width=width, position=0, )
df.TotalGoals.plot(kind='bar',color='red', ax=ax2,width=width,  position=1, )

plt.title('Results per Team for 2011 Season')

ax.set_ylabel('Total Wins')

ax2.set_ylabel('Total Goals')

plt.legend()
plt.show()

# %%
#Realised that the question was actually to plot Total Wins and Total Losses so made another chart:

sns.set()

df = df_goals_and_wins_and_losses.set_index('TeamName')

fig = plt.figure(figsize=(25,12)) 
ax = fig.add_subplot(111) 
ax2 = fig.add_subplot(111)
width = .4

df.TotalWins.plot(kind='bar',color='green',ax=ax,width=width, position=0, )
df.TotalLosses.plot(kind='bar',color='red', ax=ax2,width=width,  position=1, )

plt.title('Results per Team for 2011 Season')

ax.set_ylabel('Number of Wins(green) and Losses(red)')
plt.legend()

plt.show()
# Out:
# /Users/apple/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   if __name__ == '__main__':

# %% [markdown]
# # Question 4: Calculate Each Team's Win % in the Rain

# %%
import time
import datetime
import json
def get_keys(path):
    with open(path) as f:
        return json.load(f)

# %%
#Converted date strins into DateTime Format

def convert(s):
    return datetime.datetime.strptime(s, '%Y-%m-%d')

d = convert('2012-03-31')



df_matches.Date = df_matches.Date.astype(str)

df_matches.info()

df_matches['DateTime'] = df_matches['Date'].map(lambda x : convert(x))

df_matches
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 992 entries, 0 to 991
# Data columns (total 9 columns):
# Match_ID    992 non-null int64
# Div         992 non-null object
# Season      992 non-null int64
# Date        992 non-null object
# HomeTeam    992 non-null object
# AwayTeam    992 non-null object
# FTHG        992 non-null int64
# FTAG        992 non-null int64
# FTR         992 non-null object
# dtypes: int64(4), object(5)
# memory usage: 69.9+ KB
#      Match_ID Div  Season        Date    HomeTeam       AwayTeam  FTHG  FTAG  \
# 0        1092  D1    2011  2012-03-31    Nurnberg  Bayern Munich     0     1
# 1        1093  D1    2011  2011-12-11   Stuttgart  Bayern Munich     1     2
# 2        1094  D1    2011  2011-08-13   Wolfsburg  Bayern Munich     0     1
# 3        1095  D1    2011  2011-11-27       Mainz  Bayern Munich     3     2
# 4        1096  D1    2011  2012-02-18    Freiburg  Bayern Munich     0     0
# ..        ...  ..     ...         ...         ...            ...   ...   ...
# 987     44870  E0    2011  2012-05-13  Sunderland     Man United     0     1
# 988     44871  E0    2011  2012-05-13     Swansea      Liverpool     1     0
# 989     44872  E0    2011  2012-05-13   Tottenham         Fulham     2     0
# 990     44873  E0    2011  2012-05-13   West Brom        Arsenal     2     3
# 991     44874  E0    2011  2012-05-13       Wigan         Wolves     3     2
#
#     FTR   DateTime
# 0     A 2012-03-31
# 1     A 2011-12-11
# 2     A 2011-08-13
# 3     H 2011-11-27
# 4     D 2012-02-18
# ..   ..        ...
# 987   A 2012-05-13
# 988   H 2012-05-13
# 989   H 2012-05-13
# 990   A 2012-05-13
# 991   H 2012-05-13
#
# [992 rows x 10 columns]

# %%
#converted date into TimeStamp format - was having issues using DateTime format with DarkSky API


#tested method first
s= '2010-04-04'
time.mktime(datetime.datetime.strptime(s, "%Y-%m-%d").timetuple())
# Out:
# 1270335600.0

# %%
#used lambda function to apply to whole column

df_matches['TimeStamp'] = df_matches['Date']\
.map(lambda x: time.mktime(datetime.datetime.strptime(x, "%Y-%m-%d").timetuple()))

df_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 992 entries, 0 to 991
# Data columns (total 12 columns):
# Match_ID     992 non-null int64
# Div          992 non-null object
# Season       992 non-null int64
# Date         992 non-null object
# HomeTeam     992 non-null object
# AwayTeam     992 non-null object
# FTHG         992 non-null int64
# FTAG         992 non-null int64
# FTR          992 non-null object
# DateTime     992 non-null datetime64[ns]
# TimeStamp    992 non-null float64
# rain         992 non-null int64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(5)
# memory usage: 100.8+ KB

# %%
#converted TimeStamp from float to integer for easier parsing
df_matches.TimeStamp = df_matches.TimeStamp.astype(int)

df_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 992 entries, 0 to 991
# Data columns (total 11 columns):
# Match_ID     992 non-null int64
# Div          992 non-null object
# Season       992 non-null int64
# Date         992 non-null object
# HomeTeam     992 non-null object
# AwayTeam     992 non-null object
# FTHG         992 non-null int64
# FTAG         992 non-null int64
# FTR          992 non-null object
# DateTime     992 non-null datetime64[ns]
# TimeStamp    992 non-null int64
# dtypes: datetime64[ns](1), int64(5), object(5)
# memory usage: 85.4+ KB

# %%
import json
#saved api_key on to computer and set up link
#for security purposes

def get_keys(path):
    with open(path) as f:
        return json.load(f)
                         


keys = get_keys("/Users/apple/.secret/darksky_api.json")

api_key = keys['api_key']

# %%
#Selected first TimeStamp value to use as a test
Time = df_matches['TimeStamp'][0]
Time
# Out:
# 1333148400

# %%
#Connected to DarSkyApi with test timestamp

r = requests.get(f'https://api.darksky.net/forecast/{api_key}/52.5200,13.4050,1333148400')
r.status_code == requests.codes.ok
# Out:
# True

# %%
#examin result from api to understand shape of data and find useful information relating to rain

print(r.text)

r.json().keys()

for key in r.json().keys():
    print(key)
    value = r.json()[key] #Use standard dictionary formatting
    print(type(value)) #What type is it?
    print('\n\n') #Separate out data
# Out:
# {"latitude":52.52,"longitude":13.405,"timezone":"Europe/Berlin","currently":{"time":1333148400,"summary":"Mostly Cloudy","icon":"partly-cloudy-night","precipIntensity":0,"precipProbability":0,"temperature":46.41,"apparentTemperature":39.23,"dewPoint":40.73,"humidity":0.8,"windSpeed":18.42,"windGust":18.42,"windBearing":287,"cloudCover":0.75,"uvIndex":0,"visibility":6.216},"hourly":{"summary":"Drizzle in the morning and afternoon.","icon":"rain","data":[{"time":1333144800,"summary":"Mostly Cloudy","icon":"partly-cloudy-night","precipIntensity":0,"precipProbability":0,"temperature":46.41,"apparentTemperature":40.06,"dewPoint":40.56,"humidity":0.8,"windSpeed":14.96,"windGust":14.96,"windBearing":292,"cloudCover":0.75,"uvIndex":0,"visibility":6.216},{"time":1333148400,"summary":"Mostly Cloudy","icon":"partly-cloudy-night","precipIntensity":0,"precipProbability":0,"temperature":46.41,"apparentTemperature":39.23,"dewPoint":40.73,"humidity":0.8,"windSpeed":18.42,"windGust":18.42,"windBearing":287,"cloudCover":0.75,"uvIndex":0,"visibility":6.216},{"time":1333152000,"summary":"Mostly Cloudy","icon":"partly-cloudy-night","precipIntensity":0,"precipProbability":0,"temperature":46.41,"apparentTemperature":38.98,"dewPoint":39.55,"humidity":0.77,"windSpeed":19.55,"windGust":35.66,"windBearing":281,"cloudCover":0.75,"uvIndex":0,"visibility":6.216},{"time":1333155600,"summary":"Mostly Cloudy","icon":"partly-cloudy-night","precipIntensity":0,"precipProbability":0,"temperature":46.45,"apparentTemperature":39.28,"dewPoint":37.83,"humidity":0.72,"windSpeed":18.42,"windGust":29.9,"windBearing":286,"cloudCover":0.75,"uvIndex":0,"visibility":6.216},{"time":1333159200,"summary":"Mostly Cloudy","icon":"partly-cloudy-night","precipIntensity":0,"precipProbability":0,"temperature":46.33,"apparentTemperature":38.39,"dewPoint":37.4,"humidity":0.71,"windSpeed":22,"windGust":34.54,"windBearing":281,"cloudCover":0.75,"uvIndex":0,"visibility":6.216},{"time":1333162800,"summary":"Windy and Mostly Cloudy","icon":"wind","precipIntensity":0,"precipProbability":0,"temperature":44.6,"apparentTemperature":36.09,"dewPoint":38.43,"humidity":0.79,"windSpeed":22,"windGust":40.27,"windBearing":282,"cloudCover":0.75,"uvIndex":0,"visibility":6.216},{"time":1333166400,"summary":"Mostly Cloudy","icon":"partly-cloudy-night","precipIntensity":0,"precipProbability":0,"temperature":44.6,"apparentTemperature":35.53,"dewPoint":37.56,"humidity":0.76,"windSpeed":24.99,"windGust":32.21,"windBearing":282,"cloudCover":0.75,"uvIndex":0,"visibility":6.216},{"time":1333170000,"summary":"Mostly Cloudy","icon":"partly-cloudy-day","precipIntensity":0,"precipProbability":0,"temperature":42.8,"apparentTemperature":33.52,"dewPoint":38.33,"humidity":0.84,"windSpeed":23.01,"windGust":31.09,"windBearing":278,"cloudCover":0.75,"uvIndex":0,"visibility":6.216},{"time":1333173600,"summary":"Mostly Cloudy","icon":"partly-cloudy-day","precipIntensity":0,"precipProbability":0,"temperature":42.8,"apparentTemperature":34.16,"dewPoint":38.95,"humidity":0.86,"windSpeed":19.99,"windGust":31.09,"windBearing":289,"cloudCover":0.75,"uvIndex":0,"visibility":6.216},{"time":1333177200,"summary":"Mostly Cloudy","icon":"partly-cloudy-day","precipIntensity":0,"precipProbability":0,"temperature":43.06,"apparentTemperature":34.33,"dewPoint":37.79,"humidity":0.82,"windSpeed":20.73,"windGust":36.83,"windBearing":293,"cloudCover":0.75,"uvIndex":1,"visibility":6.216},{"time":1333180800,"summary":"Drizzle","icon":"rain","precipIntensity":0.0049,"precipProbability":0.8,"precipType":"rain","temperature":42.34,"apparentTemperature":34.28,"dewPoint":36.24,"humidity":0.79,"windSpeed":16.99,"windGust":18.36,"windBearing":305,"cloudCover":0.75,"uvIndex":2,"visibility":6.216},{"time":1333184400,"summary":"Drizzle","icon":"rain","precipIntensity":0.0018,"precipProbability":0.92,"precipType":"rain","temperature":42.41,"apparentTemperature":34.93,"dewPoint":33.78,"humidity":0.71,"windSpeed":14.96,"windGust":27.62,"windBearing":310,"clou ...
#
# latitude
# <class 'float'>
#
#
#
# longitude
# <class 'float'>
#
#
#
# timezone
# <class 'str'>
#
#
#
# currently
# <class 'dict'>
#
#
#
# hourly
# <class 'dict'>
#
#
#
# daily
# <class 'dict'>
#
#
#
# flags
# <class 'dict'>
#
#
#
# offset
# <class 'int'>

# %%
#Daily data has an icon representing weather for the day. If this is 'rain' I will count 
#the match as occuring in rainy conditions

r.json()['daily']['data'][0]['icon']
# Out:
# 'rain'

# %%
#set up test list and test dataframe to experiment with API without exceeding daily limit

TimeStamp_List = list(df_matches['TimeStamp'])

TEST_LIST = TimeStamp_List[0:10]

df_test = df_matches.head()

df_test
# Out:
#    Match_ID Div  Season        Date   HomeTeam       AwayTeam  FTHG  FTAG FTR  \
# 0      1092  D1    2011  2012-03-31   Nurnberg  Bayern Munich     0     1   A
# 1      1093  D1    2011  2011-12-11  Stuttgart  Bayern Munich     1     2   A
# 2      1094  D1    2011  2011-08-13  Wolfsburg  Bayern Munich     0     1   A
# 3      1095  D1    2011  2011-11-27      Mainz  Bayern Munich     3     2   H
# 4      1096  D1    2011  2012-02-18   Freiburg  Bayern Munich     0     0   D
#
#     DateTime   TimeStamp
# 0 2012-03-31  1333148400
# 1 2011-12-11  1323561600
# 2 2011-08-13  1313190000
# 3 2011-11-27  1322352000
# 4 2012-02-18  1329523200

# %%
#set values for berlin latitude and longitude
berlin_lat = 52.5200
berlin_lon = 13.4050

# %%
#Found that not every day has an icon key. For these days I will set the value equal to 0
#and consider them as non-rainy
#There were two ways of doing this, either using .get() or try: and except:

weather_list = []
list_of_dates = TEST_LIST
lat = berlin_lat
lon = berlin_lon

for date in list_of_dates:
        link = f'https://api.darksky.net/forecast/{api_key}/{lat},{lon},{date}'
        r = requests.get(link)
        darksky = r.json()
        weather = darksky['daily']['data'][0].get('icon', 0)
#         try:
#             weather = darksky['daily']['data'][0]['icon']
#         except KeyError:
#             weather = 0
#    
        weather_list.append(weather)
        
weather_list
# Out:
# ['rain',
#  'partly-cloudy-day',
#  'partly-cloudy-day',
#  'wind',
#  'partly-cloudy-day',
#  'rain',
#  'partly-cloudy-day',
#  'partly-cloudy-day',
#  'rain',
#  0]

# %%
#number of unique dates is far less than number of total dates
print(len(list(df_matches['TimeStamp'])))
print(len(list(df_matches['TimeStamp'].unique())))
# Out:
# 992
# 165

# %%
#found weather for each unique TimeStamp and stored results as a dictionary

lat = berlin_lat
lon = berlin_lon
list_of_dates = list(df_matches['TimeStamp'].unique())
weather_dict = {'TimeStamp': [], 'weather':[]}

for date in list_of_dates:
        link = f'https://api.darksky.net/forecast/{api_key}/{lat},{lon},{date}'
        r = requests.get(link)
        darksky = r.json()
        try:
            weather = darksky['daily']['data'][0]['icon']
        except KeyError:
            weather = 0
        weather_dict['TimeStamp'].append(date)
        weather_dict['weather'].append(weather)
    
        
        
weather_dict
# Out:
# {'TimeStamp': [1333148400,
#   1323561600,
#   1313190000,
#   1322352000,
#   1329523200,
#   1327017600,
#   1328313600,
#   1334962800,
#   1316300400,
#   1319324400,
#   1317423600,
#   1330732800,
#   1314399600,
#   1331942400,
#   1320537600,
#   1336172400,
#   1334098800,
#   1324080000,
#   1328227200,
#   1319842800,
#   1327190400,
#   1322870400,
#   1334358000,
#   1332633600,
#   1331337600,
#   1333753200,
#   1321660800,
#   1318546800,
#   1316818800,
#   1335567600,
#   1324166400,
#   1330646400,
#   1331856000,
#   1329436800,
#   1312585200,
#   1320364800,
#   1316127600,
#   1310684400,
#   1336258800,
#   1328918400,
#   1317510000,
#   1333062000,
#   1319238000,
#   1314313200,
#   1312671600,
#   1330041600,
#   1310857200,
#   1329004800,
#   1313967600,
#   1315522800,
#   1333234800,
#   1316905200,
#   1334876400,
#   1322179200,
#   1331251200,
#   1320624000,
#   1315609200,
#   1313881200,
#   1316991600,
#   1332716400,
#   1319929200,
#   1329091200,
#   1330214400,
#   1324252800,
#   1331424000,
#   1322265600,
#   1335135600,
#   1323993600,
#   1320451200,
#   1334012400,
#   1334444400,
#   1328400000,
#   1330819200,
#   1316214000,
#   1327104000,
#   1332028800,
#   1335049200,
#   1313794800,
#   1328832000,
#   1330128000,
#   1323475200,
#   1327795200,
#   1318719600,
#   1312498800,
#   1332460800,
#   1316732400,
#   1327708800,
#   1318633200,
#   1332547200,
#   1321574400,
#   1335654000,
#   1323388800,
#   1333839600,
#   1331510400,
#   1311375600,
#   1319756400,
#   1327622400,
#   1322956800,
#   1315695600,
#   1317337200,
#   1329609600,
#   1334271600,
#   1319151600,
#   1313276400,
#   1315782000,
#   1310943600,
#   1312758000,
#   1311462000,
#   1323734400,
#   1314486000,
#   1313708400,
#   1331683200,
#   1313103600,
#   1330905600,
#   1322784000,
#   1316386800,
#   1311548400,
#   1333321200,
#   1328486400,
#   1321833600,
#   1311289200,
#   1314572400,
#   1333580400,
#   1322438400,
#   1323648000,
#   1321747200,
#   1330300800,
#   1310770800,
#   1320019200,
#   1329696000,
#   1318806000,
#   1323043200,
#   1334530800,
#   1317596400,
#   1332115200,
#   1313362800,
#   1324339200,
#   1324425600,
#   1324512000,
#   1324857600,
#   1324944000,
#   1325203200,
#   1325289600,
#   1325376000,
#   1325462400,
#   1325548800,
#   1325635200,
#   1326240000,
#   1326499200,
#   1326585600,
#   1326672000,
#   1327968000,
#   1328054400,
#   1331596800,
#   1332201600,
#   1332288000,
#   1333666800,
#   1333926000,
#   1335222000,
#   1335740400,
#   1335826800,
#   1335913200,
#   1336345200,
#   1336431600,
#   1336863600],
#  'weather': ['rain',
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   'wind',
#   'partly-cloudy-day',
#   'rain',
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   'rain',
#   0,
#   0,
#   0,
#   'partly-cloudy-day',
#   0,
#   0,
#   'rain',
#   'partly-cloudy-day',
#   'rain',
#   'partly-cloudy-day',
#   0,
#   'rain',
#   'rain',
#   0,
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   0,
#   0,
#   0,
#   'rain',
#   'partly-cloudy-day',
#   0,
#   'rain',
#   'rain',
#   0,
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   'rain',
#   'partly-cloudy-day',
#   0,
#   'partly-cloudy-day',
#   0,
#   0,
#   'rain',
#   'rain',
#   'rain',
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   0,
#   0,
#   'rain',
#   'partly-cloudy-day',
#   0,
#   'partly-cloudy-day',
#   0,
#   0,
#   0,
#   0,
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   'rain',
#   0,
#   'rain',
#   0,
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   0,
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   0,
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   0,
#   0,
#   'rain',
#   'clear-day',
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   0,
#   0,
#   'cloudy',
#   0,
#   'partly-cloudy-day',
#   0,
#   'rain',
#   'rain',
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   'rain',
#   0,
#   'rain',
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   'rain',
#   'rain',
#   'rain',
#   'rain',
#   'partly-cloudy-day',
#   'rain',
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   'rain',
#   0,
#   'rain',
#   'rain',
#   'partly-cloudy-day',
#   'rain',
#   0,
#   0,
#   'rain',
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   'rain',
#   0,
#   'rain',
#   0,
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   0,
#   'partly-cloudy-day',
#   0,
#   0,
#   'partly-cloudy-day',
#   'rain',
#   'partly-cloudy-day',
#   'rain',
#   'partly-cloudy-day',
#   'rain',
#   'partly-cloudy-day',
#   'rain',
#   'partly-cloudy-day',
#   'rain',
#   'rain',
#   'rain',
#   'rain',
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   'snow',
#   0,
#   0,
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   0,
#   'rain',
#   0,
#   0,
#   0,
#   'partly-cloudy-day',
#   'partly-cloudy-day',
#   'partly-cloudy-day']}

# %%
# 47 occurances of no icon out of 165, almost 1/3
#Obviously not ideal and would like to find a better way to measure the weather if I had more time

list_of_weather = list(weather_dict.values())[1]
list_of_weather.count(0)
# Out:
# 47

# %%
#converted the output to a dataframe with TimeStamp and weather
df_weather = pd.DataFrame.from_dict(weather_dict)
df_weather
# Out:
#       TimeStamp            weather
# 0    1333148400               rain
# 1    1323561600  partly-cloudy-day
# 2    1313190000  partly-cloudy-day
# 3    1322352000               wind
# 4    1329523200  partly-cloudy-day
# ..          ...                ...
# 160  1335826800                  0
# 161  1335913200                  0
# 162  1336345200  partly-cloudy-day
# 163  1336431600  partly-cloudy-day
# 164  1336863600  partly-cloudy-day
#
# [165 rows x 2 columns]

# %%
#43 instances of rain
df_weather['weather'].value_counts()
# Out:
# partly-cloudy-day    71
# 0                    47
# rain                 43
# wind                  1
# snow                  1
# clear-day             1
# cloudy                1
# Name: weather, dtype: int64

# %%
#converted weather column to a 1 (rain) or 0 (no rain)
df_weather.loc[df_weather['weather'] != 'rain', 'weather'] = 0
df_weather.loc[df_weather['weather'] == 'rain', 'weather'] = 1

# %%
#check against previous value counts, still 43 instances of rain
df_weather['weather'].value_counts()
# Out:
# 0    122
# 1     43
# Name: weather, dtype: int64

# %%
#merge this dataframe with matches dataframe

df_matches = df_matches.merge(df_weather,how='left',left_on='TimeStamp',right_on='TimeStamp')

# %%
df_matches
# Out:
#      Match_ID Div  Season        Date    HomeTeam       AwayTeam  FTHG  FTAG  \
# 0        1092  D1    2011  2012-03-31    Nurnberg  Bayern Munich     0     1
# 1        1093  D1    2011  2011-12-11   Stuttgart  Bayern Munich     1     2
# 2        1094  D1    2011  2011-08-13   Wolfsburg  Bayern Munich     0     1
# 3        1095  D1    2011  2011-11-27       Mainz  Bayern Munich     3     2
# 4        1096  D1    2011  2012-02-18    Freiburg  Bayern Munich     0     0
# ..        ...  ..     ...         ...         ...            ...   ...   ...
# 987     44870  E0    2011  2012-05-13  Sunderland     Man United     0     1
# 988     44871  E0    2011  2012-05-13     Swansea      Liverpool     1     0
# 989     44872  E0    2011  2012-05-13   Tottenham         Fulham     2     0
# 990     44873  E0    2011  2012-05-13   West Brom        Arsenal     2     3
# 991     44874  E0    2011  2012-05-13       Wigan         Wolves     3     2
#
#     FTR   DateTime   TimeStamp  weather
# 0     A 2012-03-31  1333148400        1
# 1     A 2011-12-11  1323561600        0
# 2     A 2011-08-13  1313190000        0
# 3     H 2011-11-27  1322352000        0
# 4     D 2012-02-18  1329523200        0
# ..   ..        ...         ...      ...
# 987   A 2012-05-13  1336863600        0
# 988   H 2012-05-13  1336863600        0
# 989   H 2012-05-13  1336863600        0
# 990   A 2012-05-13  1336863600        0
# 991   H 2012-05-13  1336863600        0
#
# [992 rows x 12 columns]

# %%
#rename column from weather to rain
df_matches.rename(columns={'weather':'rain'}, inplace=True)

# %%
df_matches
# Out:
#      Match_ID Div  Season        Date    HomeTeam       AwayTeam  FTHG  FTAG  \
# 0        1092  D1    2011  2012-03-31    Nurnberg  Bayern Munich     0     1
# 1        1093  D1    2011  2011-12-11   Stuttgart  Bayern Munich     1     2
# 2        1094  D1    2011  2011-08-13   Wolfsburg  Bayern Munich     0     1
# 3        1095  D1    2011  2011-11-27       Mainz  Bayern Munich     3     2
# 4        1096  D1    2011  2012-02-18    Freiburg  Bayern Munich     0     0
# ..        ...  ..     ...         ...         ...            ...   ...   ...
# 987     44870  E0    2011  2012-05-13  Sunderland     Man United     0     1
# 988     44871  E0    2011  2012-05-13     Swansea      Liverpool     1     0
# 989     44872  E0    2011  2012-05-13   Tottenham         Fulham     2     0
# 990     44873  E0    2011  2012-05-13   West Brom        Arsenal     2     3
# 991     44874  E0    2011  2012-05-13       Wigan         Wolves     3     2
#
#     FTR   DateTime   TimeStamp  rain
# 0     A 2012-03-31  1333148400     1
# 1     A 2011-12-11  1323561600     0
# 2     A 2011-08-13  1313190000     0
# 3     H 2011-11-27  1322352000     0
# 4     D 2012-02-18  1329523200     0
# ..   ..        ...         ...   ...
# 987   A 2012-05-13  1336863600     0
# 988   H 2012-05-13  1336863600     0
# 989   H 2012-05-13  1336863600     0
# 990   A 2012-05-13  1336863600     0
# 991   H 2012-05-13  1336863600     0
#
# [992 rows x 12 columns]

# %%
#create a new dataframe of only the matches that took place under rainy conditions in 2011 Season
df_rain = df_matches[df_matches['rain'] == 1]

# %%
df_rain.reset_index(inplace=True)

df_rain
# Out:
#      index  Match_ID Div  Season        Date    HomeTeam       AwayTeam  FTHG  \
# 0        0      1092  D1    2011  2012-03-31    Nurnberg  Bayern Munich     0
# 1        5      1097  D1    2011  2012-01-20  M'gladbach  Bayern Munich     3
# 2        8      1100  D1    2011  2011-09-18  Schalke 04  Bayern Munich     0
# 3       15      1107  D1    2011  2012-05-05     FC Koln  Bayern Munich     1
# 4       18      1110  D1    2011  2011-12-17    Freiburg       Dortmund     1
# ..     ...       ...  ..     ...         ...         ...            ...   ...
# 214    975     44858  E0    2011  2012-05-06      Fulham     Sunderland     2
# 215    976     44859  E0    2011  2012-05-06  Man United        Swansea     2
# 216    977     44860  E0    2011  2012-05-06   Newcastle       Man City     0
# 217    978     44861  E0    2011  2012-05-06         QPR          Stoke     1
# 218    979     44862  E0    2011  2012-05-06      Wolves        Everton     0
#
#      FTAG FTR   DateTime   TimeStamp  rain
# 0       1   A 2012-03-31  1333148400     1
# 1       1   H 2012-01-20  1327017600     1
# 2       2   A 2011-09-18  1316300400     1
# 3       4   A 2012-05-05  1336172400     1
# 4       4   A 2011-12-17  1324080000     1
# ..    ...  ..        ...         ...   ...
# 214     1   H 2012-05-06  1336258800     1
# 215     0   H 2012-05-06  1336258800     1
# 216     2   A 2012-05-06  1336258800     1
# 217     0   H 2012-05-06  1336258800     1
# 218     0   D 2012-05-06  1336258800     1
#
# [219 rows x 13 columns]

# %%
#Swansea played no matches in the rain

print(df_matches['HomeTeam'].nunique())
print(df_rain['HomeTeam'].nunique())

set(df_matches['HomeTeam'].unique()) - set(df_rain['HomeTeam'].unique())
# Out:
# 56
# 55
# {'Swansea'}

# %%
#Created a new dataframe for Total Wins in the rain per team

Home_Wins = df_rain[df_rain['FTR'] == 'H']['HomeTeam'].value_counts()
Away_Wins = df_rain[df_rain['FTR'] == 'A']['AwayTeam'].value_counts()

df_rain_wins = pd.DataFrame(data = Home_Wins + Away_Wins).reset_index()
df_rain_wins.columns = ['TeamName', 'RainWins']
df_rain_wins.fillna(0, inplace=True)

# %%
#Created a new dataframe for Total Losses in the rain per team

Away_losses = df_rain[df_rain['FTR'] == 'A']['HomeTeam'].value_counts()
Home_losses = df_rain[df_rain['FTR'] == 'H']['AwayTeam'].value_counts()

df_rain_losses = pd.DataFrame(data = (Away_losses + Home_losses)).reset_index()
df_rain_losses.columns = ['TeamName', 'RainLosses']
df_rain_losses.fillna(0, inplace=True)
df_rain_losses
# Out:
#               TeamName  RainLosses
# 0               Aachen         0.0
# 1              Arsenal         4.0
# 2          Aston Villa         0.0
# 3        Bayern Munich         2.0
# 4            Blackburn         4.0
# 5               Bochum         5.0
# 6               Bolton         4.0
# 7         Braunschweig         0.0
# 8              Chelsea         0.0
# 9              Cottbus         3.0
# 10            Dortmund         0.0
# 11             Dresden         0.0
# 12            Duisburg         4.0
# 13       Ein Frankfurt         0.0
# 14      Erzgebirge Aue         3.0
# 15             Everton         0.0
# 16             FC Koln         6.0
# 17  Fortuna Dusseldorf         2.0
# 18       Frankfurt FSV         3.0
# 19            Freiburg         2.0
# 20              Fulham         0.0
# 21             Hamburg         3.0
# 22       Hansa Rostock         4.0
# 23              Hertha         0.0
# 24          Hoffenheim         0.0
# 25          Ingolstadt         4.0
# 26      Kaiserslautern         4.0
# 27           Karlsruhe         7.0
# 28          Leverkusen         3.0
# 29           Liverpool         0.0
# 30               Mainz         3.0
# 31            Man City         0.0
# 32          Man United         0.0
# 33         Munich 1860         4.0
# 34           Newcastle         5.0
# 35             Norwich         3.0
# 36            Nurnberg         0.0
# 37           Paderborn         0.0
# 38                 QPR         4.0
# 39          Schalke 04         4.0
# 40               Stoke         0.0
# 41           Stuttgart         0.0
# 42          Sunderland         3.0
# 43             Swansea         0.0
# 44           Tottenham         0.0
# 45        Union Berlin         5.0
# 46       Werder Bremen         5.0
# 47           West Brom         5.0
# 48               Wigan         3.0
# 49           Wolfsburg         0.0
# 50              Wolves         4.0

# %%
#Merged both dataframes for both wins and losses in the rain

df_rain_wins_and_losses = pd.merge(df_rain_wins, df_rain_losses, on='TeamName')

df_rain_wins_and_losses
# Out:
#               TeamName  RainWins  RainLosses
# 0               Aachen       0.0         0.0
# 1              Arsenal       3.0         4.0
# 2        Bayern Munich       5.0         2.0
# 3            Blackburn       0.0         4.0
# 4               Bochum       2.0         5.0
# 5               Bolton       0.0         4.0
# 6         Braunschweig       4.0         0.0
# 7              Chelsea       5.0         0.0
# 8              Cottbus       2.0         3.0
# 9             Dortmund       5.0         0.0
# 10             Dresden       0.0         0.0
# 11            Duisburg       0.0         4.0
# 12       Ein Frankfurt       2.0         0.0
# 13      Erzgebirge Aue       0.0         3.0
# 14             Everton       4.0         0.0
# 15  Fortuna Dusseldorf       0.0         2.0
# 16            Freiburg       0.0         2.0
# 17              Fulham       0.0         0.0
# 18             Hamburg       0.0         3.0
# 19       Hansa Rostock       0.0         4.0
# 20              Hertha       0.0         0.0
# 21          Ingolstadt       0.0         4.0
# 22           Karlsruhe       4.0         7.0
# 23          Leverkusen       4.0         3.0
# 24           Liverpool       2.0         0.0
# 25               Mainz       2.0         3.0
# 26            Man City       7.0         0.0
# 27          Man United       9.0         0.0
# 28         Munich 1860       8.0         4.0
# 29           Newcastle       2.0         5.0
# 30             Norwich       2.0         3.0
# 31            Nurnberg       4.0         0.0
# 32           Paderborn       0.0         0.0
# 33                 QPR       0.0         4.0
# 34          Schalke 04       3.0         4.0
# 35               Stoke       3.0         0.0
# 36           Stuttgart       0.0         0.0
# 37          Sunderland       4.0         3.0
# 38             Swansea       0.0         0.0
# 39           Tottenham       5.0         0.0
# 40        Union Berlin       4.0         5.0
# 41       Werder Bremen       0.0         5.0
# 42           West Brom       0.0         5.0
# 43               Wigan       2.0         3.0
# 44           Wolfsburg       4.0         0.0

# %%
#Used wins and losses to calculate win % in the rain, rounded to the nearest integer
df_rain_wins_and_losses['RainWin%'] = round((df_rain_wins_and_losses.RainWins/\
                                             (df_rain_wins_and_losses.RainWins+df_rain_wins_and_losses.RainLosses) * 100), 0)

df_rain_wins_and_losses.fillna(0, inplace=True)

df_rain_wins_and_losses
# Out:
#               TeamName  RainWins  RainLosses  RainWin%
# 0               Aachen       0.0         0.0       0.0
# 1              Arsenal       3.0         4.0      43.0
# 2        Bayern Munich       5.0         2.0      71.0
# 3            Blackburn       0.0         4.0       0.0
# 4               Bochum       2.0         5.0      29.0
# 5               Bolton       0.0         4.0       0.0
# 6         Braunschweig       4.0         0.0     100.0
# 7              Chelsea       5.0         0.0     100.0
# 8              Cottbus       2.0         3.0      40.0
# 9             Dortmund       5.0         0.0     100.0
# 10             Dresden       0.0         0.0       0.0
# 11            Duisburg       0.0         4.0       0.0
# 12       Ein Frankfurt       2.0         0.0     100.0
# 13      Erzgebirge Aue       0.0         3.0       0.0
# 14             Everton       4.0         0.0     100.0
# 15  Fortuna Dusseldorf       0.0         2.0       0.0
# 16            Freiburg       0.0         2.0       0.0
# 17              Fulham       0.0         0.0       0.0
# 18             Hamburg       0.0         3.0       0.0
# 19       Hansa Rostock       0.0         4.0       0.0
# 20              Hertha       0.0         0.0       0.0
# 21          Ingolstadt       0.0         4.0       0.0
# 22           Karlsruhe       4.0         7.0      36.0
# 23          Leverkusen       4.0         3.0      57.0
# 24           Liverpool       2.0         0.0     100.0
# 25               Mainz       2.0         3.0      40.0
# 26            Man City       7.0         0.0     100.0
# 27          Man United       9.0         0.0     100.0
# 28         Munich 1860       8.0         4.0      67.0
# 29           Newcastle       2.0         5.0      29.0
# 30             Norwich       2.0         3.0      40.0
# 31            Nurnberg       4.0         0.0     100.0
# 32           Paderborn       0.0         0.0       0.0
# 33                 QPR       0.0         4.0       0.0
# 34          Schalke 04       3.0         4.0      43.0
# 35               Stoke       3.0         0.0     100.0
# 36           Stuttgart       0.0         0.0       0.0
# 37          Sunderland       4.0         3.0      57.0
# 38             Swansea       0.0         0.0       0.0
# 39           Tottenham       5.0         0.0     100.0
# 40        Union Berlin       4.0         5.0      44.0
# 41       Werder Bremen       0.0         5.0       0.0
# 42           West Brom       0.0         5.0       0.0
# 43               Wigan       2.0         3.0      40.0
# 44           Wolfsburg       4.0         0.0     100.0

# %%
# Used my results to retrospectively make a Class for WeatherGetter that uses
# DarkSky API to get the daily weather icon for a given longitude and latitude

class WeatherGetter(object):
    
 
    def __init__(self,lat,long):
        self.lat = lat
        self.long = long
        self.url = 'https://api.darksky.net/forecast/{}/{},{},{}'
        
         
    def get_keys(self,path="/Users/apple/.secret/darksky_api.json"):
        with open(path) as f:
            keys = json.load(f)
        return keys["api_key"]

    def weather_day(self, date):
        api_key = self.get_keys()
        weather = requests.get(self.url.format(api_key,self.lat,self.long,date))
        darksky = weather.json()
        try:
            weather = darksky['daily']['data'][0]['icon']
        except KeyError:
            weather = 0
        return weather
           
    def weather_list(self, date_list = []):
        weather_dict = {'TimeStamp': [], 'weather':[]}
        for date in date_list:
            weather_dict['TimeStamp'].append(date)
            weather_dict['weather'].append(self.weather_day(date))
        return weather_dict

# %%
#Tested WeatherGetter

lat = berlin_lat
long = berlin_lon

weather_test = WeatherGetter(berlin_lat, berlin_lon)
timestamp_weather = weather_test.weather_list(list(df_matches['TimeStamp'].head(10)))
df_timestamp_weather = pd.DataFrame(timestamp_weather)

df_timestamp_weather.loc[df_timestamp_weather['weather'] != 'rain', 'weather'] = 0
df_timestamp_weather.loc[df_timestamp_weather['weather'] == 'rain', 'weather'] = 1

df_timestamp_weather
# Out:
#     TimeStamp  weather
# 0  1333148400        1
# 1  1323561600        0
# 2  1313190000        0
# 3  1322352000        0
# 4  1329523200        0
# 5  1327017600        1
# 6  1328313600        0
# 7  1334962800        0
# 8  1316300400        1
# 9  1319324400        0

# %% [markdown]
# # Question 5: Upload to Mongo

# %%
#Merged RainWin% with goals, wins and losses into one final dataframe to upload to Mongo

df_final = pd.merge(df_goals_and_wins_and_losses, df_rain_wins_and_losses, on='TeamName')

df_final.drop(['RainWins', 'RainLosses'],axis=1, inplace=True)



df_final
# Out:
#               TeamName  TotalGoals  TotalWins  TotalLosses  RainWin%
# 0               Aachen          30          6         15.0       0.0
# 1              Arsenal          74         21         10.0      43.0
# 2        Bayern Munich          77         23          7.0      71.0
# 3            Blackburn          48          8         23.0       0.0
# 4               Bochum          41         10         17.0      29.0
# 5               Bolton          46         10         22.0       0.0
# 6         Braunschweig          37         10          9.0     100.0
# 7              Chelsea          65         18         10.0     100.0
# 8              Cottbus          30          8         15.0      40.0
# 9             Dortmund          80         25          3.0     100.0
# 10             Dresden          50         12         13.0       0.0
# 11            Duisburg          42         10         15.0       0.0
# 12       Ein Frankfurt          76         20          6.0     100.0
# 13      Erzgebirge Aue          31          8         15.0       0.0
# 14             Everton          50         15         12.0     100.0
# 15  Fortuna Dusseldorf          64         16          4.0       0.0
# 16            Freiburg          45         10         14.0       0.0
# 17              Fulham          48         14         14.0       0.0
# 18             Hamburg          35          8         14.0       0.0
# 19       Hansa Rostock          34          5         17.0       0.0
# 20              Hertha          38          7         17.0       0.0
# 21          Ingolstadt          43          8         13.0       0.0
# 22           Karlsruhe          34          9         19.0      36.0
# 23          Leverkusen          52         15         10.0      57.0
# 24           Liverpool          47         14         14.0     100.0
# 25               Mainz          47          9         13.0      40.0
# 26            Man City          93         28          0.0     100.0
# 27          Man United          89         28          5.0     100.0
# 28         Munich 1860          62         17         11.0      67.0
# 29           Newcastle          56         19         11.0      29.0
# 30             Norwich          52         12         15.0      40.0
# 31            Nurnberg          38         12         16.0     100.0
# 32           Paderborn          51         17          7.0       0.0
# 33                 QPR          43         10         21.0       0.0
# 34          Schalke 04          74         20         10.0      43.0
# 35               Stoke          36         11         15.0     100.0
# 36           Stuttgart          63         15         11.0       0.0
# 37          Sunderland          45         11         15.0      57.0
# 38             Swansea          44         12         15.0       0.0
# 39           Tottenham          66         20          9.0     100.0
# 40        Union Berlin          55         14         14.0      44.0
# 41       Werder Bremen          49         11         14.0       0.0
# 42           West Brom          45         13         17.0       0.0
# 43               Wigan          42         11         17.0      40.0
# 44           Wolfsburg          47         13         16.0     100.0

# %%
#Connected to Mongo

import pymongo
import requests

myclient = pymongo.MongoClient("mongodb://127.0.0.1:27017/")

# grab a database from your server 
mydb = myclient['Football_Data']

myclient.list_database_names()
# Out:
# ['Football_Data', 'admin', 'config', 'example_data', 'local']

# %%
mycollection = mydb['Football_Collection']
mydb.list_collection_names()
# Out:
# ['img_collection', 'Football_Collection']

# %%
#converted dataframe to a dictionary so it could be uploaded to Mongo

df_mongo = df_final.to_dict(orient = 'records')

# %%
df_mongo
# Out:
# [{'TeamName': 'Aachen',
#   'TotalGoals': 30,
#   'TotalWins': 6,
#   'TotalLosses': 15.0,
#   'RainWin%': 0.0},
#  {'TeamName': 'Arsenal',
#   'TotalGoals': 74,
#   'TotalWins': 21,
#   'TotalLosses': 10.0,
#   'RainWin%': 43.0},
#  {'TeamName': 'Bayern Munich',
#   'TotalGoals': 77,
#   'TotalWins': 23,
#   'TotalLosses': 7.0,
#   'RainWin%': 71.0},
#  {'TeamName': 'Blackburn',
#   'TotalGoals': 48,
#   'TotalWins': 8,
#   'TotalLosses': 23.0,
#   'RainWin%': 0.0},
#  {'TeamName': 'Bochum',
#   'TotalGoals': 41,
#   'TotalWins': 10,
#   'TotalLosses': 17.0,
#   'RainWin%': 29.0},
#  {'TeamName': 'Bolton',
#   'TotalGoals': 46,
#   'TotalWins': 10,
#   'TotalLosses': 22.0,
#   'RainWin%': 0.0},
#  {'TeamName': 'Braunschweig',
#   'TotalGoals': 37,
#   'TotalWins': 10,
#   'TotalLosses': 9.0,
#   'RainWin%': 100.0},
#  {'TeamName': 'Chelsea',
#   'TotalGoals': 65,
#   'TotalWins': 18,
#   'TotalLosses': 10.0,
#   'RainWin%': 100.0},
#  {'TeamName': 'Cottbus',
#   'TotalGoals': 30,
#   'TotalWins': 8,
#   'TotalLosses': 15.0,
#   'RainWin%': 40.0},
#  {'TeamName': 'Dortmund',
#   'TotalGoals': 80,
#   'TotalWins': 25,
#   'TotalLosses': 3.0,
#   'RainWin%': 100.0},
#  {'TeamName': 'Dresden',
#   'TotalGoals': 50,
#   'TotalWins': 12,
#   'TotalLosses': 13.0,
#   'RainWin%': 0.0},
#  {'TeamName': 'Duisburg',
#   'TotalGoals': 42,
#   'TotalWins': 10,
#   'TotalLosses': 15.0,
#   'RainWin%': 0.0},
#  {'TeamName': 'Ein Frankfurt',
#   'TotalGoals': 76,
#   'TotalWins': 20,
#   'TotalLosses': 6.0,
#   'RainWin%': 100.0},
#  {'TeamName': 'Erzgebirge Aue',
#   'TotalGoals': 31,
#   'TotalWins': 8,
#   'TotalLosses': 15.0,
#   'RainWin%': 0.0},
#  {'TeamName': 'Everton',
#   'TotalGoals': 50,
#   'TotalWins': 15,
#   'TotalLosses': 12.0,
#   'RainWin%': 100.0},
#  {'TeamName': 'Fortuna Dusseldorf',
#   'TotalGoals': 64,
#   'TotalWins': 16,
#   'TotalLosses': 4.0,
#   'RainWin%': 0.0},
#  {'TeamName': 'Freiburg',
#   'TotalGoals': 45,
#   'TotalWins': 10,
#   'TotalLosses': 14.0,
#   'RainWin%': 0.0},
#  {'TeamName': 'Fulham',
#   'TotalGoals': 48,
#   'TotalWins': 14,
#   'TotalLosses': 14.0,
#   'RainWin%': 0.0},
#  {'TeamName': 'Hamburg',
#   'TotalGoals': 35,
#   'TotalWins': 8,
#   'TotalLosses': 14.0,
#   'RainWin%': 0.0},
#  {'TeamName': 'Hansa Rostock',
#   'TotalGoals': 34,
#   'TotalWins': 5,
#   'TotalLosses': 17.0,
#   'RainWin%': 0.0},
#  {'TeamName': 'Hertha',
#   'TotalGoals': 38,
#   'TotalWins': 7,
#   'TotalLosses': 17.0,
#   'RainWin%': 0.0},
#  {'TeamName': 'Ingolstadt',
#   'TotalGoals': 43,
#   'TotalWins': 8,
#   'TotalLosses': 13.0,
#   'RainWin%': 0.0},
#  {'TeamName': 'Karlsruhe',
#   'TotalGoals': 34,
#   'TotalWins': 9,
#   'TotalLosses': 19.0,
#   'RainWin%': 36.0},
#  {'TeamName': 'Leverkusen',
#   'TotalGoals': 52,
#   'TotalWins': 15,
#   'TotalLosses': 10.0,
#   'RainWin%': 57.0},
#  {'TeamName': 'Liverpool',
#   'TotalGoals': 47,
#   'TotalWins': 14,
#   'TotalLosses': 14.0,
#   'RainWin%': 100.0},
#  {'TeamName': 'Mainz',
#   'TotalGoals': 47,
#   'TotalWins': 9,
#   'TotalLosses': 13.0,
#   'RainWin%': 40.0},
#  {'TeamName': 'Man City',
#   'TotalGoals': 93,
#   'TotalWins': 28,
#   'TotalLosses': 0.0,
#   'RainWin%': 100.0},
#  {'TeamName': 'Man United',
#   'TotalGoals': 89,
#   'TotalWins': 28,
#   'TotalLosses': 5.0,
#   'RainWin%': 100.0},
#  {'TeamName': 'Munich 1860',
#   'TotalGoals': 62,
#   'TotalWins': 17,
#   'TotalLosses': 11.0,
#   'RainWin%': 67.0},
#  {'TeamName': 'Newcastle',
#   'TotalGoals': 56,
#   'TotalWins': 19,
#   'TotalLosses': 11.0,
#   'RainWin%': 29.0},
#  {'TeamName': 'Norwich',
#   'TotalGoals': 52,
#   'TotalWins': 12,
#   'TotalLosses': 15.0,
#   'RainWin%': 40.0},
#  {'TeamName': 'Nurnberg',
#   'TotalGoals': 38,
#   'TotalWins': 12,
#   'TotalLosses': 16.0,
#   'RainWin%': 100.0},
#  {'TeamName': 'Paderborn',
#   'TotalGoals': 51,
#   'TotalWins': 17,
#   'TotalLosses': 7.0,
#   'RainWin%': 0.0},
#  {'TeamName': 'QPR',
#   'TotalGoals': 43,
#   'TotalWins': 10,
#   'TotalLosses': 21.0,
#   'RainWin%': 0.0},
#  {'TeamName': 'Schalke 04',
#   'TotalGoals': 74,
#   'TotalWins': 20,
#   'TotalLosses': 10.0,
#   'RainWin%': 43.0},
#  {'TeamName': 'Stoke',
#   'TotalGoals': 36,
#   'TotalWins': 11,
#   'TotalLosses': 15.0,
#   'RainWin%': 100.0},
#  {'TeamName': 'Stuttgart',
#   'TotalGoals': 63,
#   'TotalWins': 15,
#   'TotalLosses': 11.0,
#   'RainWin%': 0.0},
#  {'TeamName': 'Sunderland',
#   'TotalGoals': 45,
#   'TotalWins': 11,
#   'TotalLosses': 15.0,
#   'RainWin%': 57.0},
#  {'TeamName': 'Swansea',
#   'TotalGoals': 44,
#   'TotalWins': 12,
#   'TotalLosses': 15.0,
#   'RainWin%': 0.0},
#  {'TeamName': 'Tottenham',
#   'TotalGoals': 66,
#   'TotalWins': 20,
#   'TotalLosses': 9.0,
#   'RainWin%': 100.0},
#  {'TeamName': 'Union Berlin',
#   'TotalGoals': 55,
#   'TotalWins': 14,
#   'TotalLosses': 14.0,
#   'RainWin%': 44.0},
#  {'TeamName': 'Werder Bremen',
#   'TotalGoals': 49,
#   'TotalWins': 11,
#   'TotalLosses': 14.0,
#   'RainWin%': 0.0},
#  {'TeamName': 'West Brom',
#   'TotalGoals': 45,
#   'TotalWins': 13,
#   'TotalLosses': 17.0,
#   'RainWin%': 0.0},
#  {'TeamName': 'Wigan',
#   'TotalGoals': 42,
#   'TotalWins': 11,
#   'TotalLosses': 17.0,
#   'RainWin%': 40.0},
#  {'TeamName': 'Wolfsburg',
#   'TotalGoals': 47,
#   'TotalWins': 13,
#   'TotalLosses': 16.0,
#   'RainWin%': 100.0}]

# %%
#dataframe uploaded
mycollection.insert_many(df_mongo)

# %%
#test

query = mycollection.find({'TeamName':'Bayern Munich'})
for document in query:
    print(document)
# Out:
# {'_id': ObjectId('5e340dab5b0a5b441a3af8ea'), 'TeamName': 'Bayern Munich', 'TotalGoals': 77, 'TotalWins': 23, 'TotalLosses': 7.0, 'RainWin%': 71.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe27'), 'TeamName': 'Bayern Munich', 'TotalGoals': 77, 'TotalWins': 23, 'TotalLosses': 7.0, 'RainWin%': 71.0}

# %%
#Upload Image to Mongo
resp = requests.get\
('https://github.com/joekryan/FlatironMod2Project/blob/master/Images/Win_Loss_Visualisation.png')

img = resp.content
newcollection = mydb['img_collection']
img
len(img)
# Out:
# 65678

# %%
from IPython.display import Image
Image(resp.content)

# %%
img_dict = {'description': 'visualisation', 'image': img}
newcollection.insert_one(img_dict)

# %%
_.inserted_id
# Out:
# ObjectId('5e3433cca2c66f7e621cfe52')

# %%
#defined mongo Class MongoHandler to upload dataframes and images to MongoDB

class MongoHandler(object):
    
    

    def __init__(self):
        pass


    def CreateCollection(self,name =""):
        self.mycollection  = name
        return self.mycollection
    
    def upload_dataframe(self, DataFrame):
        dictionary_df = DataFrame.to_dict(orient='records')
        mycollection.insert_many(dictionary_df)
        return 'Mongo Done'
    
    def upload_image(self, description, imgurl):
        resp = requests.get(imgurl)
        img = resp.content
        img_dict = {'tag': description, 'image': img}
        mycollection.insert_one(img_dict)
        return 'Image Uploaded to Mongo'

# %%
#Test MongoHandler

df_test
# Out:
#    Match_ID Div  Season        Date   HomeTeam       AwayTeam  FTHG  FTAG FTR  \
# 0      1092  D1    2011  2012-03-31   Nurnberg  Bayern Munich     0     1   A
# 1      1093  D1    2011  2011-12-11  Stuttgart  Bayern Munich     1     2   A
# 2      1094  D1    2011  2011-08-13  Wolfsburg  Bayern Munich     0     1   A
# 3      1095  D1    2011  2011-11-27      Mainz  Bayern Munich     3     2   H
# 4      1096  D1    2011  2012-02-18   Freiburg  Bayern Munich     0     0   D
#
#     DateTime   TimeStamp
# 0 2012-03-31  1333148400
# 1 2011-12-11  1323561600
# 2 2011-08-13  1313190000
# 3 2011-11-27  1322352000
# 4 2012-02-18  1329523200

# %%
TestMongo = MongoHandler()

# %%
TestMongo.CreateCollection("Test_Collection")
# Out:
# 'Test_Collection'

# %%
TestMongo.upload_dataframe(df_test)
# Out:
# 'Mongo Done'

# %%
TestMongo.upload_image('Visualisation', \
                       'https://github.com/joekryan/FlatironMod2Project/blob/master/Win_Loss_Visualisation.png')
# Out:
# 'Image Uploaded to Mongo'

# %%
query = mycollection.find({})

for document in query:
    print(document)
# Out:
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8ba'), 'TotalGoals': 30, 'TotalWins': 6, 'TotalLosses': 15.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8bb'), 'TotalGoals': 74, 'TotalWins': 21, 'TotalLosses': 10.0, 'RainWin%': 43.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8bc'), 'TotalGoals': 77, 'TotalWins': 23, 'TotalLosses': 7.0, 'RainWin%': 71.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8bd'), 'TotalGoals': 48, 'TotalWins': 8, 'TotalLosses': 23.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8be'), 'TotalGoals': 41, 'TotalWins': 10, 'TotalLosses': 17.0, 'RainWin%': 29.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8bf'), 'TotalGoals': 46, 'TotalWins': 10, 'TotalLosses': 22.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8c0'), 'TotalGoals': 37, 'TotalWins': 10, 'TotalLosses': 9.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8c1'), 'TotalGoals': 65, 'TotalWins': 18, 'TotalLosses': 10.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8c2'), 'TotalGoals': 30, 'TotalWins': 8, 'TotalLosses': 15.0, 'RainWin%': 40.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8c3'), 'TotalGoals': 80, 'TotalWins': 25, 'TotalLosses': 3.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8c4'), 'TotalGoals': 50, 'TotalWins': 12, 'TotalLosses': 13.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8c5'), 'TotalGoals': 42, 'TotalWins': 10, 'TotalLosses': 15.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8c6'), 'TotalGoals': 76, 'TotalWins': 20, 'TotalLosses': 6.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8c7'), 'TotalGoals': 31, 'TotalWins': 8, 'TotalLosses': 15.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8c8'), 'TotalGoals': 50, 'TotalWins': 15, 'TotalLosses': 12.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8c9'), 'TotalGoals': 64, 'TotalWins': 16, 'TotalLosses': 4.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8ca'), 'TotalGoals': 45, 'TotalWins': 10, 'TotalLosses': 14.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8cb'), 'TotalGoals': 48, 'TotalWins': 14, 'TotalLosses': 14.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8cc'), 'TotalGoals': 35, 'TotalWins': 8, 'TotalLosses': 14.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8cd'), 'TotalGoals': 34, 'TotalWins': 5, 'TotalLosses': 17.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8ce'), 'TotalGoals': 38, 'TotalWins': 7, 'TotalLosses': 17.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8cf'), 'TotalGoals': 43, 'TotalWins': 8, 'TotalLosses': 13.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8d0'), 'TotalGoals': 34, 'TotalWins': 9, 'TotalLosses': 19.0, 'RainWin%': 36.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8d1'), 'TotalGoals': 52, 'TotalWins': 15, 'TotalLosses': 10.0, 'RainWin%': 57.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8d2'), 'TotalGoals': 47, 'TotalWins': 14, 'TotalLosses': 14.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8d3'), 'TotalGoals': 47, 'TotalWins': 9, 'TotalLosses': 13.0, 'RainWin%': 40.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8d4'), 'TotalGoals': 93, 'TotalWins': 28, 'TotalLosses': 0.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8d5'), 'TotalGoals': 89, 'TotalWins': 28, 'TotalLosses': 5.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8d6'), 'TotalGoals': 62, 'TotalWins': 17, 'TotalLosses': 11.0, 'RainWin%': 67.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8d7'), 'TotalGoals': 56, 'TotalWins': 19, 'TotalLosses': 11.0, 'RainWin%': 29.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8d8'), 'TotalGoals': 52, 'TotalWins': 12, 'TotalLosses': 15.0, 'RainWin%': 40.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8d9'), 'TotalGoals': 38, 'TotalWins': 12, 'TotalLosses': 16.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8da'), 'TotalGoals': 51, 'TotalWins': 17, 'TotalLosses': 7.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8db'), 'TotalGoals': 43, 'TotalWins': 10, 'TotalLosses': 21.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8dc'), 'TotalGoals': 74, 'TotalWins': 20, 'TotalLosses': 10.0, 'RainWin%': 43.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8dd'), 'TotalGoals': 36, 'TotalWins': 11, 'TotalLosses': 15.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8de'), 'TotalGoals': 63, 'TotalWins': 15, 'TotalLosses': 11.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8df'), 'TotalGoals': 45, 'TotalWins': 11, 'TotalLosses': 15.0, 'RainWin%': 57.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8e0'), 'TotalGoals': 44, 'TotalWins': 12, 'TotalLosses': 15.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8e1'), 'TotalGoals': 66, 'TotalWins': 20, 'TotalLosses': 9.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8e2'), 'TotalGoals': 55, 'TotalWins': 14, 'TotalLosses': 14.0, 'RainWin%': 44.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8e3'), 'TotalGoals': 49, 'TotalWins': 11, 'TotalLosses': 14.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8e4'), 'TotalGoals': 45, 'TotalWins': 13, 'TotalLosses': 17.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8e5'), 'TotalGoals': 42, 'TotalWins': 11, 'TotalLosses': 17.0, 'RainWin%': 40.0}
# {'_id': ObjectId('5e340d1b5b0a5b441a3af8e6'), 'TotalGoals': 47, 'TotalWins': 13, 'TotalLosses': 16.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af8e8'), 'TeamName': 'Aachen', 'TotalGoals': 30, 'TotalWins': 6, 'TotalLosses': 15.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af8e9'), 'TeamName': 'Arsenal', 'TotalGoals': 74, 'TotalWins': 21, 'TotalLosses': 10.0, 'RainWin%': 43.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af8ea'), 'TeamName': 'Bayern Munich', 'TotalGoals': 77, 'TotalWins': 23, 'TotalLosses': 7.0, 'RainWin%': 71.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af8eb'), 'TeamName': 'Blackburn', 'TotalGoals': 48, 'TotalWins': 8, 'TotalLosses': 23.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af8ec'), 'TeamName': 'Bochum', 'TotalGoals': 41, 'TotalWins': 10, 'TotalLosses': 17.0, 'RainWin%': 29.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af8ed'), 'TeamName': 'Bolton', 'TotalGoals': 46, 'TotalWins': 10, 'TotalLosses': 22.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af8ee'), 'TeamName': 'Braunschweig', 'TotalGoals': 37, 'TotalWins': 10, 'TotalLosses': 9.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af8ef'), 'TeamName': 'Chelsea', 'TotalGoals': 65, 'TotalWins': 18, 'TotalLosses': 10.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af8f0'), 'TeamName': 'Cottbus', 'TotalGoals': 30, 'TotalWins': 8, 'TotalLosses': 15.0, 'RainWin%': 40.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af8f1'), 'TeamName': 'Dortmund', 'TotalGoals': 80, 'TotalWins': 25, 'TotalLosses': 3.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af8f2'), 'TeamName': 'Dresden', 'TotalGoals': 50, 'TotalWins': 12, 'TotalLosses': 13.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af8f3'), 'TeamName': 'Duisburg', 'TotalGoals': 42, 'TotalWins': 10, 'TotalLosses': 15.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af8f4'), 'TeamName': 'Ein Frankfurt', 'TotalGoals': 76, 'TotalWins': 20, 'TotalLosses': 6.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af8f5'), 'TeamName': 'Erzgebirge Aue', 'TotalGoals': 31, 'TotalWins': 8, 'TotalLosses': 15.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af8f6'), 'TeamName': 'Everton', 'TotalGoals': 50, 'TotalWins': 15, 'TotalLosses': 12.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af8f7'), 'TeamName': 'Fortuna Dusseldorf', 'TotalGoals': 64, 'TotalWins': 16, 'TotalLosses': 4.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af8f8'), 'TeamName': 'Freiburg', 'TotalGoals': 45, 'TotalWins': 10, 'TotalLosses': 14.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af8f9'), 'TeamName': 'Fulham', 'TotalGoals': 48, 'TotalWins': 14, 'TotalLosses': 14.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af8fa'), 'TeamName': 'Hamburg', 'TotalGoals': 35, 'TotalWins': 8, 'TotalLosses': 14.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af8fb'), 'TeamName': 'Hansa Rostock', 'TotalGoals': 34, 'TotalWins': 5, 'TotalLosses': 17.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af8fc'), 'TeamName': 'Hertha', 'TotalGoals': 38, 'TotalWins': 7, 'TotalLosses': 17.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af8fd'), 'TeamName': 'Ingolstadt', 'TotalGoals': 43, 'TotalWins': 8, 'TotalLosses': 13.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af8fe'), 'TeamName': 'Karlsruhe', 'TotalGoals': 34, 'TotalWins': 9, 'TotalLosses': 19.0, 'RainWin%': 36.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af8ff'), 'TeamName': 'Leverkusen', 'TotalGoals': 52, 'TotalWins': 15, 'TotalLosses': 10.0, 'RainWin%': 57.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af900'), 'TeamName': 'Liverpool', 'TotalGoals': 47, 'TotalWins': 14, 'TotalLosses': 14.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af901'), 'TeamName': 'Mainz', 'TotalGoals': 47, 'TotalWins': 9, 'TotalLosses': 13.0, 'RainWin%': 40.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af902'), 'TeamName': 'Man City', 'TotalGoals': 93, 'TotalWins': 28, 'TotalLosses': 0.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af903'), 'TeamName': 'Man United', 'TotalGoals': 89, 'TotalWins': 28, 'TotalLosses': 5.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af904'), 'TeamName': 'Munich 1860', 'TotalGoals': 62, 'TotalWins': 17, 'TotalLosses': 11.0, 'RainWin%': 67.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af905'), 'TeamName': 'Newcastle', 'TotalGoals': 56, 'TotalWins': 19, 'TotalLosses': 11.0, 'RainWin%': 29.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af906'), 'TeamName': 'Norwich', 'TotalGoals': 52, 'TotalWins': 12, 'TotalLosses': 15.0, 'RainWin%': 40.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af907'), 'TeamName': 'Nurnberg', 'TotalGoals': 38, 'TotalWins': 12, 'TotalLosses': 16.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af908'), 'TeamName': 'Paderborn', 'TotalGoals': 51, 'TotalWins': 17, 'TotalLosses': 7.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af909'), 'TeamName': 'QPR', 'TotalGoals': 43, 'TotalWins': 10, 'TotalLosses': 21.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af90a'), 'TeamName': 'Schalke 04', 'TotalGoals': 74, 'TotalWins': 20, 'TotalLosses': 10.0, 'RainWin%': 43.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af90b'), 'TeamName': 'Stoke', 'TotalGoals': 36, 'TotalWins': 11, 'TotalLosses': 15.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af90c'), 'TeamName': 'Stuttgart', 'TotalGoals': 63, 'TotalWins': 15, 'TotalLosses': 11.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af90d'), 'TeamName': 'Sunderland', 'TotalGoals': 45, 'TotalWins': 11, 'TotalLosses': 15.0, 'RainWin%': 57.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af90e'), 'TeamName': 'Swansea', 'TotalGoals': 44, 'TotalWins': 12, 'TotalLosses': 15.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af90f'), 'TeamName': 'Tottenham', 'TotalGoals': 66, 'TotalWins': 20, 'TotalLosses': 9.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af910'), 'TeamName': 'Union Berlin', 'TotalGoals': 55, 'TotalWins': 14, 'TotalLosses': 14.0, 'RainWin%': 44.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af911'), 'TeamName': 'Werder Bremen', 'TotalGoals': 49, 'TotalWins': 11, 'TotalLosses': 14.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af912'), 'TeamName': 'West Brom', 'TotalGoals': 45, 'TotalWins': 13, 'TotalLosses': 17.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af913'), 'TeamName': 'Wigan', 'TotalGoals': 42, 'TotalWins': 11, 'TotalLosses': 17.0, 'RainWin%': 40.0}
# {'_id': ObjectId('5e340dab5b0a5b441a3af914'), 'TeamName': 'Wolfsburg', 'TotalGoals': 47, 'TotalWins': 13, 'TotalLosses': 16.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e3414155b0a5b441a3af916'), 'Match_ID': 1092, 'Div': 'D1', 'Season': 2011, 'Date': '2012-03-31', 'HomeTeam': 'Nurnberg', 'AwayTeam': 'Bayern Munich', 'FTHG': 0, 'FTAG': 1, 'FTR': 'A', 'DateTime': datetime.datetime(2012, 3, 31, 0, 0), 'TimeStamp': 1333148400}
# {'_id': ObjectId('5e3414155b0a5b441a3af917'), 'Match_ID': 1093, 'Div': 'D1', 'Season': 2011, 'Date': '2011-12-11', 'HomeTeam': 'Stuttgart', 'AwayTeam': 'Bayern Munich', 'FTHG': 1, 'FTAG': 2, 'FTR': 'A', 'DateTime': datetime.datetime(2011, 12, 11, 0, 0), 'TimeStamp': 1323561600}
# {'_id': ObjectId('5e3414155b0a5b441a3af918'), 'Match_ID': 1094, 'Div': 'D1', 'Season': 2011, 'Date': '2011-08-13', 'HomeTeam': 'Wolfsburg', 'AwayTeam': 'Bayern Munich', 'FTHG': 0, 'FTAG': 1, 'FTR': 'A', 'DateTime': datetime.datetime(2011, 8, 13, 0, 0), 'TimeStamp': 1313190000}
# {'_id': ObjectId('5e3414155b0a5b441a3af919'), 'Match_ID': 1095, 'Div': 'D1', 'Season': 2011, 'Date': '2011-11-27', 'HomeTeam': 'Mainz', 'AwayTeam': 'Bayern Munich', 'FTHG': 3, 'FTAG': 2, 'FTR': 'H', 'DateTime': datetime.datetime(2011, 11, 27, 0, 0), 'TimeStamp': 1322352000}
# {'_id': ObjectId('5e3414155b0a5b441a3af91a'), 'Match_ID': 1096, 'Div': 'D1', 'Season': 2011, 'Date': '2012-02-18', 'HomeTeam': 'Freiburg', 'AwayTeam': 'Bayern Munich', 'FTHG': 0, 'FTAG': 0, 'FTR': 'D', 'DateTime': datetime.datetime(2012, 2, 18, 0, 0), 'TimeStamp': 1329523200}
# {'_id': ObjectId('5e34161c5b0a5b441a3af91d'), 'Match_ID': 1092, 'Div': 'D1', 'Season': 2011, 'Date': '2012-03-31', 'HomeTeam': 'Nurnberg', 'AwayTeam': 'Bayern Munich', 'FTHG': 0, 'FTAG': 1, 'FTR': 'A', 'DateTime': datetime.datetime(2012, 3, 31, 0, 0), 'TimeStamp': 1333148400}
# {'_id': ObjectId('5e34161c5b0a5b441a3af91e'), 'Match_ID': 1093, 'Div': 'D1', 'Season': 2011, 'Date': '2011-12-11', 'HomeTeam': 'Stuttgart', 'AwayTeam': 'Bayern Munich', 'FTHG': 1, 'FTAG': 2, 'FTR': 'A', 'DateTime': datetime.datetime(2011, 12, 11, 0, 0), 'TimeStamp': 1323561600}
# {'_id': ObjectId('5e34161c5b0a5b441a3af91f'), 'Match_ID': 1094, 'Div': 'D1', 'Season': 2011, 'Date': '2011-08-13', 'HomeTeam': 'Wolfsburg', 'AwayTeam': 'Bayern Munich', 'FTHG': 0, 'FTAG': 1, 'FTR': 'A', 'DateTime': datetime.datetime(2011, 8, 13, 0, 0), 'TimeStamp': 1313190000}
# {'_id': ObjectId('5e34161c5b0a5b441a3af920'), 'Match_ID': 1095, 'Div': 'D1', 'Season': 2011, 'Date': '2011-11-27', 'HomeTeam': 'Mainz', 'AwayTeam': 'Bayern Munich', 'FTHG': 3, 'FTAG': 2, 'FTR': 'H', 'DateTime': datetime.datetime(2011, 11, 27, 0, 0), 'TimeStamp': 1322352000}
# {'_id': ObjectId('5e34161c5b0a5b441a3af921'), 'Match_ID': 1096, 'Div': 'D1', 'Season': 2011, 'Date': '2012-02-18', 'HomeTeam': 'Freiburg', 'AwayTeam': 'Bayern Munich', 'FTHG': 0, 'FTAG': 0, 'FTR': 'D', 'DateTime': datetime.datetime(2012, 2, 18, 0, 0), 'TimeStamp': 1329523200}
# {'_id': ObjectId('5e3416b65b0a5b441a3af923'), 'Match_ID': 1092, 'Div': 'D1', 'Season': 2011, 'Date': '2012-03-31', 'HomeTeam': 'Nurnberg', 'AwayTeam': 'Bayern Munich', 'FTHG': 0, 'FTAG': 1, 'FTR': 'A', 'DateTime': datetime.datetime(2012, 3, 31, 0, 0), 'TimeStamp': 1333148400}
# {'_id': ObjectId('5e3416b65b0a5b441a3af924'), 'Match_ID': 1093, 'Div': 'D1', 'Season': 2011, 'Date': '2011-12-11', 'HomeTeam': 'Stuttgart', 'AwayTeam': 'Bayern Munich', 'FTHG': 1, 'FTAG': 2, 'FTR': 'A', 'DateTime': datetime.datetime(2011, 12, 11, 0, 0), 'TimeStamp': 1323561600}
# {'_id': ObjectId('5e3416b65b0a5b441a3af925'), 'Match_ID': 1094, 'Div': 'D1', 'Season': 2011, 'Date': '2011-08-13', 'HomeTeam': 'Wolfsburg', 'AwayTeam': 'Bayern Munich', 'FTHG': 0, 'FTAG': 1, 'FTR': 'A', 'DateTime': datetime.datetime(2011, 8, 13, 0, 0), 'TimeStamp': 1313190000}
# {'_id': ObjectId('5e3416b65b0a5b441a3af926'), 'Match_ID': 1095, 'Div': 'D1', 'Season': 2011, 'Date': '2011-11-27', 'HomeTeam': 'Mainz', 'AwayTeam': 'Bayern Munich', 'FTHG': 3, 'FTAG': 2, 'FTR': 'H', 'DateTime': datetime.datetime(2011, 11, 27, 0, 0), 'TimeStamp': 1322352000}
# {'_id': ObjectId('5e3416b65b0a5b441a3af927'), 'Match_ID': 1096, 'Div': 'D1', 'Season': 2011, 'Date': '2012-02-18', 'HomeTeam': 'Freiburg', 'AwayTeam': 'Bayern Munich', 'FTHG': 0, 'FTAG': 0, 'FTR': 'D', 'DateTime': datetime.datetime(2012, 2, 18, 0, 0), 'TimeStamp': 1329523200}
# {'_id': ObjectId('5e3417035b0a5b441a3af929'), 'Match_ID': 1092, 'Div': 'D1', 'Season': 2011, 'Date': '2012-03-31', 'HomeTeam': 'Nurnberg', 'AwayTeam': 'Bayern Munich', 'FTHG': 0, 'FTAG': 1, 'FTR': 'A', 'DateTime': datetime.datetime(2012, 3, 31, 0, 0), 'TimeStamp': 1333148400}
# {'_id': ObjectId('5e3417035b0a5b441a3af92a'), 'Match_ID': 1093, 'Div': 'D1', 'Season': 2011, 'Date': '2011-12-11', 'HomeTeam': 'Stuttgart', 'AwayTeam': 'Bayern Munich', 'FTHG': 1, 'FTAG': 2, 'FTR': 'A', 'DateTime': datetime.datetime(2011, 12, 11, 0, 0), 'TimeStamp': 1323561600}
# {'_id': ObjectId('5e3417035b0a5b441a3af92b'), 'Match_ID': 1094, 'Div': 'D1', 'Season': 2011, 'Date': '2011-08-13', 'HomeTeam': 'Wolfsburg', 'AwayTeam': 'Bayern Munich', 'FTHG': 0, 'FTAG': 1, 'FTR': 'A', 'DateTime': datetime.datetime(2011, 8, 13, 0, 0), 'TimeStamp': 1313190000}
# {'_id': ObjectId('5e3417035b0a5b441a3af92c'), 'Match_ID': 1095, 'Div': 'D1', 'Season': 2011, 'Date': '2011-11-27', 'HomeTeam': 'Mainz', 'AwayTeam': 'Bayern Munich', 'FTHG': 3, 'FTAG': 2, 'FTR': 'H', 'DateTime': datetime.datetime(2011, 11, 27, 0, 0), 'TimeStamp': 1322352000}
# {'_id': ObjectId('5e3417035b0a5b441a3af92d'), 'Match_ID': 1096, 'Div': 'D1', 'Season': 2011, 'Date': '2012-02-18', 'HomeTeam': 'Freiburg', 'AwayTeam': 'Bayern Munich', 'FTHG': 0, 'FTAG': 0, 'FTR': 'D', 'DateTime': datetime.datetime(2012, 2, 18, 0, 0), 'TimeStamp': 1329523200}
# {'_id': ObjectId('5e3417065b0a5b441a3af92e'), 'tag': 'Visualisation', 'image': b'\n\n\n\n\n\n<!DOCTYPE html>\n<html lang="en">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars0.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars1.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars2.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars3.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n\n\n\n  <link crossorigin="anonymous" media="all" integrity="sha512-ouI5UScWVQasLY7xrTyxOmvoOYEdJ7Mr2jttdNrXlazKaQP8ODIVxoAZQvTYh8kn0PmonJfuY6TOSepXEblj+w==" rel="stylesheet" href="https://github.githubassets.com/assets/frameworks-a2e2395127165506ac2d8ef1ad3cb13a.css" />\n  <link crossorigin="anonymous" media="all" integrity="sha512-9GykgbDFf/u6MFQhN5tmqAC4W30+7jjbbqfE9GqoHN8+mmAT9mYcZ1LSQ2thUEaZdhfGkajORCK+8oK4k90MUw==" rel="stylesheet" href="https://github.githubassets.com/assets/site-f46ca481b0c57ffbba305421379b66a8.css" />\n    <link crossorigin="anonymous" media="all" integrity="sha512-Lf45wpzBBafbvYCiP6whhi1zzbc0gs4CN34gI71l9Y7g4q+zOB7PDflEJH25hQvqQgrMiPLbvQp3MYodNwycgQ==" rel="stylesheet" href="https://github.githubassets.com/assets/github-2dfe39c29cc105a7dbbd80a23fac2186.css" />\n    \n    \n    \n    \n\n\n  <meta name="viewport" content="width=device-width">\n  \n  <title>FlatironMod2Project/Win_Loss_Visualisation.png at master \xc2\xb7 joekryan/FlatironMod2Project \xc2\xb7 GitHub</title>\n    <meta name="description" content="Contribute to joekryan/FlatironMod2Project development by creating an account on GitHub.">\n    <link rel="search" type="application/opensearchdescription+xml" href="/opensearch.xml" title="GitHub">\n  <link rel="fluid-icon" href="https://github.com/fluidicon.png" title="GitHub">\n  <meta property="fb:app_id" content="1401488693436528">\n\n    <meta name="twitter:image:src" content="https://avatars2.githubusercontent.com/u/57951585?s=400&amp;v=4" /><meta name="twitter:site" content="@github" /><meta name="twitter:card" content="summary" /><meta name="twitter:title" content="joekryan/FlatironMod2Project" /><meta name="twitter:description" content="Contribute to joekryan/FlatironMod2Project development by creating an account on GitHub." />\n    <meta property="og:image" content="https://avatars2.githubusercontent.com/u/57951585?s=400&amp;v=4" /><meta property="og:site_name" content="GitHub" /><meta property="og:type" content="object" /><meta property="og:title" content="joekryan/FlatironMod2Project" /><meta property="og:url" content="https://github.com/joekryan/FlatironMod2Project" /><meta property="og:description" content="Contribute to joekryan/FlatironMod2Project development by creating an account on GitHub." />\n\n  <link rel="assets" href="https://github.githubassets.com/">\n  \n  \n\n    <meta name="request-id" content="B953:3B742:FEBB92:1799C42:5E341706" data-pjax-transient="true" /><meta name="html-safe-nonce" content="f46c4e3a5287879376d9b413511d517b1c1ab0ad" data-pjax-transient="true" /><meta name="visitor-payload" content="eyJyZWZlcnJlciI6bnVsbCwicmVxdWVzdF9pZCI6IkI5NTM6M0I3NDI6RkVCQjkyOjE3OTlDNDI6NUUzNDE3MDYiLCJ2aXNpdG9yX2lkIjoiMTM1ODAwNzM3OTk4MjI5Mjc0MiIsInJlZ2lvbl9lZGdlIjoiYW1zIiwicmVnaW9uX3JlbmRlciI6ImlhZCJ9" data-pjax-transient="true" /><meta name="visitor-hmac" content="1a20f2cbbd7e2763cfe18300f3eb8f5a754cda12686d92823676b505025f0669" data-pjax-transient="true" />\n\n\n\n  \n\n  <meta name="selected-link" value="repo_source" data-pjax-transient>\n\n      <meta name="google-site-verification" content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU">\n    <meta name="google-site-verification" content="ZzhVyEFwb7w3e0-uOTltm8Jsck2F5StVihD0exw2fsA">\n    <meta name="google-site-verification" content="GXs5KoUUkNCoa ...
# {'_id': ObjectId('5e3417465b0a5b441a3af92f'), 'Match_ID': 1092, 'Div': 'D1', 'Season': 2011, 'Date': '2012-03-31', 'HomeTeam': 'Nurnberg', 'AwayTeam': 'Bayern Munich', 'FTHG': 0, 'FTAG': 1, 'FTR': 'A', 'DateTime': datetime.datetime(2012, 3, 31, 0, 0), 'TimeStamp': 1333148400}
# {'_id': ObjectId('5e3417465b0a5b441a3af930'), 'Match_ID': 1093, 'Div': 'D1', 'Season': 2011, 'Date': '2011-12-11', 'HomeTeam': 'Stuttgart', 'AwayTeam': 'Bayern Munich', 'FTHG': 1, 'FTAG': 2, 'FTR': 'A', 'DateTime': datetime.datetime(2011, 12, 11, 0, 0), 'TimeStamp': 1323561600}
# {'_id': ObjectId('5e3417465b0a5b441a3af931'), 'Match_ID': 1094, 'Div': 'D1', 'Season': 2011, 'Date': '2011-08-13', 'HomeTeam': 'Wolfsburg', 'AwayTeam': 'Bayern Munich', 'FTHG': 0, 'FTAG': 1, 'FTR': 'A', 'DateTime': datetime.datetime(2011, 8, 13, 0, 0), 'TimeStamp': 1313190000}
# {'_id': ObjectId('5e3417465b0a5b441a3af932'), 'Match_ID': 1095, 'Div': 'D1', 'Season': 2011, 'Date': '2011-11-27', 'HomeTeam': 'Mainz', 'AwayTeam': 'Bayern Munich', 'FTHG': 3, 'FTAG': 2, 'FTR': 'H', 'DateTime': datetime.datetime(2011, 11, 27, 0, 0), 'TimeStamp': 1322352000}
# {'_id': ObjectId('5e3417465b0a5b441a3af933'), 'Match_ID': 1096, 'Div': 'D1', 'Season': 2011, 'Date': '2012-02-18', 'HomeTeam': 'Freiburg', 'AwayTeam': 'Bayern Munich', 'FTHG': 0, 'FTAG': 0, 'FTR': 'D', 'DateTime': datetime.datetime(2012, 2, 18, 0, 0), 'TimeStamp': 1329523200}
# {'_id': ObjectId('5e3417495b0a5b441a3af934'), 'tag': 'Visualisation', 'image': b'\n\n\n\n\n\n<!DOCTYPE html>\n<html lang="en">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars0.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars1.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars2.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars3.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n\n\n\n  <link crossorigin="anonymous" media="all" integrity="sha512-ouI5UScWVQasLY7xrTyxOmvoOYEdJ7Mr2jttdNrXlazKaQP8ODIVxoAZQvTYh8kn0PmonJfuY6TOSepXEblj+w==" rel="stylesheet" href="https://github.githubassets.com/assets/frameworks-a2e2395127165506ac2d8ef1ad3cb13a.css" />\n  <link crossorigin="anonymous" media="all" integrity="sha512-9GykgbDFf/u6MFQhN5tmqAC4W30+7jjbbqfE9GqoHN8+mmAT9mYcZ1LSQ2thUEaZdhfGkajORCK+8oK4k90MUw==" rel="stylesheet" href="https://github.githubassets.com/assets/site-f46ca481b0c57ffbba305421379b66a8.css" />\n    <link crossorigin="anonymous" media="all" integrity="sha512-Lf45wpzBBafbvYCiP6whhi1zzbc0gs4CN34gI71l9Y7g4q+zOB7PDflEJH25hQvqQgrMiPLbvQp3MYodNwycgQ==" rel="stylesheet" href="https://github.githubassets.com/assets/github-2dfe39c29cc105a7dbbd80a23fac2186.css" />\n    \n    \n    \n    \n\n\n  <meta name="viewport" content="width=device-width">\n  \n  <title>FlatironMod2Project/Win_Loss_Visualisation.png at master \xc2\xb7 joekryan/FlatironMod2Project \xc2\xb7 GitHub</title>\n    <meta name="description" content="Contribute to joekryan/FlatironMod2Project development by creating an account on GitHub.">\n    <link rel="search" type="application/opensearchdescription+xml" href="/opensearch.xml" title="GitHub">\n  <link rel="fluid-icon" href="https://github.com/fluidicon.png" title="GitHub">\n  <meta property="fb:app_id" content="1401488693436528">\n\n    <meta name="twitter:image:src" content="https://avatars2.githubusercontent.com/u/57951585?s=400&amp;v=4" /><meta name="twitter:site" content="@github" /><meta name="twitter:card" content="summary" /><meta name="twitter:title" content="joekryan/FlatironMod2Project" /><meta name="twitter:description" content="Contribute to joekryan/FlatironMod2Project development by creating an account on GitHub." />\n    <meta property="og:image" content="https://avatars2.githubusercontent.com/u/57951585?s=400&amp;v=4" /><meta property="og:site_name" content="GitHub" /><meta property="og:type" content="object" /><meta property="og:title" content="joekryan/FlatironMod2Project" /><meta property="og:url" content="https://github.com/joekryan/FlatironMod2Project" /><meta property="og:description" content="Contribute to joekryan/FlatironMod2Project development by creating an account on GitHub." />\n\n  <link rel="assets" href="https://github.githubassets.com/">\n  \n  \n\n    <meta name="request-id" content="933D:3B9A4:E3DD92:1535F21:5E341748" data-pjax-transient="true" /><meta name="html-safe-nonce" content="4eae24ef678afac644a145af9426622dab2b2fa4" data-pjax-transient="true" /><meta name="visitor-payload" content="eyJyZWZlcnJlciI6bnVsbCwicmVxdWVzdF9pZCI6IjkzM0Q6M0I5QTQ6RTNERDkyOjE1MzVGMjE6NUUzNDE3NDgiLCJ2aXNpdG9yX2lkIjoiMTM0MjY0NTQyNDQyNTgwMTU0NCIsInJlZ2lvbl9lZGdlIjoiYW1zIiwicmVnaW9uX3JlbmRlciI6ImlhZCJ9" data-pjax-transient="true" /><meta name="visitor-hmac" content="d86b1571a46d0ddbef097b29b0f782e98738ca30f98032fdc822b9b8fca57f43" data-pjax-transient="true" />\n\n\n\n  \n\n  <meta name="selected-link" value="repo_source" data-pjax-transient>\n\n      <meta name="google-site-verification" content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU">\n    <meta name="google-site-verification" content="ZzhVyEFwb7w3e0-uOTltm8Jsck2F5StVihD0exw2fsA">\n    <meta name="google-site-verification" content="GXs5KoUUkNCoa ...
# {'_id': ObjectId('5e3433cba2c66f7e621cfe25'), 'TeamName': 'Aachen', 'TotalGoals': 30, 'TotalWins': 6, 'TotalLosses': 15.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe26'), 'TeamName': 'Arsenal', 'TotalGoals': 74, 'TotalWins': 21, 'TotalLosses': 10.0, 'RainWin%': 43.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe27'), 'TeamName': 'Bayern Munich', 'TotalGoals': 77, 'TotalWins': 23, 'TotalLosses': 7.0, 'RainWin%': 71.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe28'), 'TeamName': 'Blackburn', 'TotalGoals': 48, 'TotalWins': 8, 'TotalLosses': 23.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe29'), 'TeamName': 'Bochum', 'TotalGoals': 41, 'TotalWins': 10, 'TotalLosses': 17.0, 'RainWin%': 29.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe2a'), 'TeamName': 'Bolton', 'TotalGoals': 46, 'TotalWins': 10, 'TotalLosses': 22.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe2b'), 'TeamName': 'Braunschweig', 'TotalGoals': 37, 'TotalWins': 10, 'TotalLosses': 9.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe2c'), 'TeamName': 'Chelsea', 'TotalGoals': 65, 'TotalWins': 18, 'TotalLosses': 10.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe2d'), 'TeamName': 'Cottbus', 'TotalGoals': 30, 'TotalWins': 8, 'TotalLosses': 15.0, 'RainWin%': 40.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe2e'), 'TeamName': 'Dortmund', 'TotalGoals': 80, 'TotalWins': 25, 'TotalLosses': 3.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe2f'), 'TeamName': 'Dresden', 'TotalGoals': 50, 'TotalWins': 12, 'TotalLosses': 13.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe30'), 'TeamName': 'Duisburg', 'TotalGoals': 42, 'TotalWins': 10, 'TotalLosses': 15.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe31'), 'TeamName': 'Ein Frankfurt', 'TotalGoals': 76, 'TotalWins': 20, 'TotalLosses': 6.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe32'), 'TeamName': 'Erzgebirge Aue', 'TotalGoals': 31, 'TotalWins': 8, 'TotalLosses': 15.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe33'), 'TeamName': 'Everton', 'TotalGoals': 50, 'TotalWins': 15, 'TotalLosses': 12.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe34'), 'TeamName': 'Fortuna Dusseldorf', 'TotalGoals': 64, 'TotalWins': 16, 'TotalLosses': 4.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe35'), 'TeamName': 'Freiburg', 'TotalGoals': 45, 'TotalWins': 10, 'TotalLosses': 14.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe36'), 'TeamName': 'Fulham', 'TotalGoals': 48, 'TotalWins': 14, 'TotalLosses': 14.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe37'), 'TeamName': 'Hamburg', 'TotalGoals': 35, 'TotalWins': 8, 'TotalLosses': 14.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe38'), 'TeamName': 'Hansa Rostock', 'TotalGoals': 34, 'TotalWins': 5, 'TotalLosses': 17.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe39'), 'TeamName': 'Hertha', 'TotalGoals': 38, 'TotalWins': 7, 'TotalLosses': 17.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe3a'), 'TeamName': 'Ingolstadt', 'TotalGoals': 43, 'TotalWins': 8, 'TotalLosses': 13.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe3b'), 'TeamName': 'Karlsruhe', 'TotalGoals': 34, 'TotalWins': 9, 'TotalLosses': 19.0, 'RainWin%': 36.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe3c'), 'TeamName': 'Leverkusen', 'TotalGoals': 52, 'TotalWins': 15, 'TotalLosses': 10.0, 'RainWin%': 57.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe3d'), 'TeamName': 'Liverpool', 'TotalGoals': 47, 'TotalWins': 14, 'TotalLosses': 14.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe3e'), 'TeamName': 'Mainz', 'TotalGoals': 47, 'TotalWins': 9, 'TotalLosses': 13.0, 'RainWin%': 40.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe3f'), 'TeamName': 'Man City', 'TotalGoals': 93, 'TotalWins': 28, 'TotalLosses': 0.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe40'), 'TeamName': 'Man United', 'TotalGoals': 89, 'TotalWins': 28, 'TotalLosses': 5.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe41'), 'TeamName': 'Munich 1860', 'TotalGoals': 62, 'TotalWins': 17, 'TotalLosses': 11.0, 'RainWin%': 67.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe42'), 'TeamName': 'Newcastle', 'TotalGoals': 56, 'TotalWins': 19, 'TotalLosses': 11.0, 'RainWin%': 29.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe43'), 'TeamName': 'Norwich', 'TotalGoals': 52, 'TotalWins': 12, 'TotalLosses': 15.0, 'RainWin%': 40.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe44'), 'TeamName': 'Nurnberg', 'TotalGoals': 38, 'TotalWins': 12, 'TotalLosses': 16.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe45'), 'TeamName': 'Paderborn', 'TotalGoals': 51, 'TotalWins': 17, 'TotalLosses': 7.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe46'), 'TeamName': 'QPR', 'TotalGoals': 43, 'TotalWins': 10, 'TotalLosses': 21.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe47'), 'TeamName': 'Schalke 04', 'TotalGoals': 74, 'TotalWins': 20, 'TotalLosses': 10.0, 'RainWin%': 43.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe48'), 'TeamName': 'Stoke', 'TotalGoals': 36, 'TotalWins': 11, 'TotalLosses': 15.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe49'), 'TeamName': 'Stuttgart', 'TotalGoals': 63, 'TotalWins': 15, 'TotalLosses': 11.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe4a'), 'TeamName': 'Sunderland', 'TotalGoals': 45, 'TotalWins': 11, 'TotalLosses': 15.0, 'RainWin%': 57.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe4b'), 'TeamName': 'Swansea', 'TotalGoals': 44, 'TotalWins': 12, 'TotalLosses': 15.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe4c'), 'TeamName': 'Tottenham', 'TotalGoals': 66, 'TotalWins': 20, 'TotalLosses': 9.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe4d'), 'TeamName': 'Union Berlin', 'TotalGoals': 55, 'TotalWins': 14, 'TotalLosses': 14.0, 'RainWin%': 44.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe4e'), 'TeamName': 'Werder Bremen', 'TotalGoals': 49, 'TotalWins': 11, 'TotalLosses': 14.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe4f'), 'TeamName': 'West Brom', 'TotalGoals': 45, 'TotalWins': 13, 'TotalLosses': 17.0, 'RainWin%': 0.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe50'), 'TeamName': 'Wigan', 'TotalGoals': 42, 'TotalWins': 11, 'TotalLosses': 17.0, 'RainWin%': 40.0}
# {'_id': ObjectId('5e3433cba2c66f7e621cfe51'), 'TeamName': 'Wolfsburg', 'TotalGoals': 47, 'TotalWins': 13, 'TotalLosses': 16.0, 'RainWin%': 100.0}
# {'_id': ObjectId('5e3433cca2c66f7e621cfe53'), 'Match_ID': 1092, 'Div': 'D1', 'Season': 2011, 'Date': '2012-03-31', 'HomeTeam': 'Nurnberg', 'AwayTeam': 'Bayern Munich', 'FTHG': 0, 'FTAG': 1, 'FTR': 'A', 'DateTime': datetime.datetime(2012, 3, 31, 0, 0), 'TimeStamp': 1333148400}
# {'_id': ObjectId('5e3433cca2c66f7e621cfe54'), 'Match_ID': 1093, 'Div': 'D1', 'Season': 2011, 'Date': '2011-12-11', 'HomeTeam': 'Stuttgart', 'AwayTeam': 'Bayern Munich', 'FTHG': 1, 'FTAG': 2, 'FTR': 'A', 'DateTime': datetime.datetime(2011, 12, 11, 0, 0), 'TimeStamp': 1323561600}
# {'_id': ObjectId('5e3433cca2c66f7e621cfe55'), 'Match_ID': 1094, 'Div': 'D1', 'Season': 2011, 'Date': '2011-08-13', 'HomeTeam': 'Wolfsburg', 'AwayTeam': 'Bayern Munich', 'FTHG': 0, 'FTAG': 1, 'FTR': 'A', 'DateTime': datetime.datetime(2011, 8, 13, 0, 0), 'TimeStamp': 1313190000}
# {'_id': ObjectId('5e3433cca2c66f7e621cfe56'), 'Match_ID': 1095, 'Div': 'D1', 'Season': 2011, 'Date': '2011-11-27', 'HomeTeam': 'Mainz', 'AwayTeam': 'Bayern Munich', 'FTHG': 3, 'FTAG': 2, 'FTR': 'H', 'DateTime': datetime.datetime(2011, 11, 27, 0, 0), 'TimeStamp': 1322352000}
# {'_id': ObjectId('5e3433cca2c66f7e621cfe57'), 'Match_ID': 1096, 'Div': 'D1', 'Season': 2011, 'Date': '2012-02-18', 'HomeTeam': 'Freiburg', 'AwayTeam': 'Bayern Munich', 'FTHG': 0, 'FTAG': 0, 'FTR': 'D', 'DateTime': datetime.datetime(2012, 2, 18, 0, 0), 'TimeStamp': 1329523200}
# {'_id': ObjectId('5e3433cda2c66f7e621cfe58'), 'tag': 'Visualisation', 'image': b'\n\n\n\n\n\n<!DOCTYPE html>\n<html lang="en">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars0.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars1.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars2.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars3.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n\n\n\n  <link crossorigin="anonymous" media="all" integrity="sha512-ouI5UScWVQasLY7xrTyxOmvoOYEdJ7Mr2jttdNrXlazKaQP8ODIVxoAZQvTYh8kn0PmonJfuY6TOSepXEblj+w==" rel="stylesheet" href="https://github.githubassets.com/assets/frameworks-a2e2395127165506ac2d8ef1ad3cb13a.css" />\n  <link crossorigin="anonymous" media="all" integrity="sha512-9GykgbDFf/u6MFQhN5tmqAC4W30+7jjbbqfE9GqoHN8+mmAT9mYcZ1LSQ2thUEaZdhfGkajORCK+8oK4k90MUw==" rel="stylesheet" href="https://github.githubassets.com/assets/site-f46ca481b0c57ffbba305421379b66a8.css" />\n    <link crossorigin="anonymous" media="all" integrity="sha512-Lf45wpzBBafbvYCiP6whhi1zzbc0gs4CN34gI71l9Y7g4q+zOB7PDflEJH25hQvqQgrMiPLbvQp3MYodNwycgQ==" rel="stylesheet" href="https://github.githubassets.com/assets/github-2dfe39c29cc105a7dbbd80a23fac2186.css" />\n    \n    \n    \n    \n\n\n  <meta name="viewport" content="width=device-width">\n  \n  <title>FlatironMod2Project/Win_Loss_Visualisation.png at master \xc2\xb7 joekryan/FlatironMod2Project \xc2\xb7 GitHub</title>\n    <meta name="description" content="Contribute to joekryan/FlatironMod2Project development by creating an account on GitHub.">\n    <link rel="search" type="application/opensearchdescription+xml" href="/opensearch.xml" title="GitHub">\n  <link rel="fluid-icon" href="https://github.com/fluidicon.png" title="GitHub">\n  <meta property="fb:app_id" content="1401488693436528">\n\n    <meta name="twitter:image:src" content="https://avatars2.githubusercontent.com/u/57951585?s=400&amp;v=4" /><meta name="twitter:site" content="@github" /><meta name="twitter:card" content="summary" /><meta name="twitter:title" content="joekryan/FlatironMod2Project" /><meta name="twitter:description" content="Contribute to joekryan/FlatironMod2Project development by creating an account on GitHub." />\n    <meta property="og:image" content="https://avatars2.githubusercontent.com/u/57951585?s=400&amp;v=4" /><meta property="og:site_name" content="GitHub" /><meta property="og:type" content="object" /><meta property="og:title" content="joekryan/FlatironMod2Project" /><meta property="og:url" content="https://github.com/joekryan/FlatironMod2Project" /><meta property="og:description" content="Contribute to joekryan/FlatironMod2Project development by creating an account on GitHub." />\n\n  <link rel="assets" href="https://github.githubassets.com/">\n  \n  \n\n    <meta name="request-id" content="985B:28289:10E0231:18C8F85:5E3433CC" data-pjax-transient="true" /><meta name="html-safe-nonce" content="2e8a3e06cd35398b995a69c56633a53f655eece0" data-pjax-transient="true" /><meta name="visitor-payload" content="eyJyZWZlcnJlciI6bnVsbCwicmVxdWVzdF9pZCI6Ijk4NUI6MjgyODk6MTBFMDIzMToxOEM4Rjg1OjVFMzQzM0NDIiwidmlzaXRvcl9pZCI6IjM2MDAzMjA0MDExODQ2NjY1NzIiLCJyZWdpb25fZWRnZSI6ImFtcyIsInJlZ2lvbl9yZW5kZXIiOiJpYWQifQ==" data-pjax-transient="true" /><meta name="visitor-hmac" content="097b0773c132da0c184a4d64d917860a35f97173b0f211fbb672f72dad512c42" data-pjax-transient="true" />\n\n\n\n  \n\n  <meta name="selected-link" value="repo_source" data-pjax-transient>\n\n      <meta name="google-site-verification" content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU">\n    <meta name="google-site-verification" content="ZzhVyEFwb7w3e0-uOTltm8Jsck2F5StVihD0exw2fsA">\n    <meta name="google-site-verification" content="GXs5KoUU ...
